# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, Dataset
import pandas as pd
from transformers import AutoTokenizer, DistilBertModel
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
classification = 'nouns'

# %%
# create a simple torch model with 1 fully connected layer

class Net(nn.Module):
    def __init__(self, input_size):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(input_size, 2)

    def forward(self, x):
        # apply relu on the output of the fully connected layer
        # x = F.relu(self.fc1(x))
        x = self.fc1(x)
        return x

# %%
words = [
    "apple", "book", "car", "dog", "cat", "house", "tree", "friend", "time", "money",
    "heart", "sun", "moon", "sky", "water", "fire", "earth", "flower", "city", "music",
    "child", "parent", "school", "job", "love", "smile", "day", "night", "star", "cloud",
    "bird", "fish", "food", "computer", "phone", "internet", "coffee", "tea", "shoes", "hat",
    "dream", "goal", "team", "game", "hope", "fear", "joy", "anger", "peace", "war",
    "friendship", "family", "health", "beauty", "knowledge", "power", "nature", "history", "science",
    "art", "happiness", "sadness", "color", "mind", "body", "soul", "memory", "experience", "idea",
    "faith", "truth", "lie", "problem", "solution", "question", "answer", "light", "darkness", "wind",
    "rain", "snow", "smell", "taste", "touch", "sound", "silence", "joy", "freedom", "future",
    "past", "present", "purpose", "journey", "adventure", "discovery", "challenge", "victory", "defeat"
    "time", "person", "year", "way", "day", "man", "government", "company", "number", "child",
    "part", "place", "case", "group", "problem", "fact", "eye", "friend", "charge", "point",
    "home", "hand", "job", "food", "example", "place", "book", "end", "government", "water",
    "room", "mother", "area", "money", "story", "fact", "month", "lot", "right", "study",
    "face", "word", "business", "question", "school", "reason", "air", "mind", "law", "company",
    "word", "number", "order", "example", "market", "name", "door", "value", "position", "body",
    "problem", "theory", "class", "child", "car", "house", "year", "arm", "lot", "father",
    "word", "team", "result", "school", "name", "line", "place", "end", "government", "oil",
    "line", "end", "fire", "company", "example", "name", "water", "person", "home", "country",
    "industry", "back", "mother", "house", "name", "side", "period", "city", "case", "job",
    "air", "team", "problem", "name", "number", "part", "car", "hand", "body", "example",
    "home", "water", "point", "name", "company", "room", "group", "fact", "eye", "lot",
    "question", "place", "government", "word", "end", "number", "problem", "part", "home",
    "case", "job", "lot", "team", "person", "result", "line", "city", "air", "example",
    "water", "place", "number", "name", "door", "money", "team", "word", "person", "end",
    "position", "body", "fire", "problem", "car", "word", "house", "value", "fact", "theory",
    "breeze", "cascade", "serenity", "quasar", "equinox", "fluke", "havoc", "gadget", "nuance", "oblivion",
    "paradox", "quagmire", "reverie", "saga", "thistle", "vortex", "whimsy", "xenon", "yarn", "zenith",
    "clique", "dynamo", "epoch", "fiasco", "glyph", "halo", "icon", "jargon", "kaleidoscope", "labyrinth",
    "memento", "nirvana", "opulence", "pinnacle", "quintessence", "rendezvous", "sonnet", "tryst", "utopia", "vista",
    "wanderlust", "xylophone", "yearning", "zealot", "albatross", "bivouac", "catalyst", "dystopia", "effigy", "fandango"
    "companion", "toast", "lounge", "combination", "majesty", "nutrient", "bark", "rest", "drainage", "time", "drink",
    "journey", "shipment", "measure", "cutlery", "catch", "flutter", "moo", "commute", "score", "indulgence", "cutting",
    "containment", "communication", "transportation", "slice", "drying", "tote", "nurture", "breakfast", "cut", "brush",
    "competition", "signal", "mobility", "conformity", "comfort", "pause", "input", "hygiene", "click", "health",
    "entertainment", "halt", "crunch", "softness", "control", "loyalty", "formality", "individuality", "gallop",
    "protection", "gathering", "pattern", "productivity", "purr", "decoration", "bite", "accessory", "reflection",
    "grace", "support", "scoop", "tick", "flight", "navigation", "descent", "voyage", "thrill", "hug", "knowledge",
    "shield", "transit", "solitude", "heat", "celebration", "adventure", "song", "elegance", "recreation", "roar",
    "trumpet", "container", "aroma", "childhood", "measurement", "sanitation", "vibration", "growth", "safety", "swing",
    "sharpness", "stride", "graze", "excitement", "acidity", "prong", "munch", "person", "bicycle", "car", "motorcycle",
    "airplane", "bus", "train", "truck", "boat", "traffic light", "fire hydrant", "stop sign", "parking meter", "bench",
    "bird", "cat", "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
    "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat", "baseball glove",
    "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup", "fork", "knife", "spoon", "bowl", "banana",
    "apple", "sandwich", "orange", "broccoli", "carrot", "hot dog", "pizza", "donut", "cake", "chair", "couch",
    "potted plant", "bed", "dining table", "toilet", "tv", "laptop", "mouse", "remote", "keyboard", "cell phone",
    "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors", "teddy bear",
    "hair drier", "toothbrush", "%", "company", "year", "market", "trading", "Thanksgiving", "Mr.", "U.S.", "New",
    "Corp.", "York", "Containers", "Securities", "Industries", "Materials", "Soviets", "years", "shares", "prices",
    "cents", "funds"
]

most_common_words = []

# remove duplicates
words = list(set(words))
most_common_words = list(set(most_common_words))

print(len(words))
print(len(most_common_words))

assert len(list(set(words + most_common_words))) == len(words) + len(most_common_words)
# Out:
# 381
# 0

# %%
non_words = [
    "run", "jump", "eat", "sleep", "think", "happy", "fast", "slow", "beautiful", "smart",
    "quickly", "easily", "always", "never", "under", "over", "beside", "between", "through", "with",
    "and", "but", "or", "because", "although", "well", "yes", "no", "oh", "wow", "ouch",
    "go", "come", "stop", "start", "win", "lose", "hot", "cold", "loud", "soft",
    "bright", "dark", "high", "low", "near", "far", "big", "small", "old", "new",
    "first", "last", "next", "previous", "good", "bad", "happy", "sad", "rich", "poor",
    "early", "late", "hard", "easy", "simple", "complex", "right", "wrong", "true", "false",
    "up", "down", "in", "out", "on", "off", "up", "down", "here", "there",
    "now", "then", "today", "tomorrow", "yesterday", "soon", "later", "before", "after", "while",
    "once", "twice", "thrice", "nevertheless", "however", "suddenly", "finally", "quickly", "slowly", "nowadays",
    "some", "many", "few", "most", "none", "all", "each", "every", "somebody", "nobody",
    "something", "nothing", "somewhere", "nowhere", "anywhere", "everywhere", "this", "that", "these", "those",
    "which", "what", "who", "whom", "whose", "where", "when", "why", "how", "whether",
    "if", "unless", "because", "since", "although", "though", "while", "before", "after", "when",
    "and", "or", "but", "nor", "for", "so", "yet", "either", "neither", "however"
    "is", "are", "was", "were", "am", "be", "being", "been", "has", "have",
    "had", "do", "does", "did", "doing", "will", "would", "shall", "should", "can",
    "could", "may", "might", "must", "ought", "ain't", "isn't", "aren't", "wasn't", "weren't",
    "hasn't", "haven't", "hadn't", "don't", "doesn't", "didn't", "won't", "wouldn't", "shan't", "shouldn't",
    "can't", "cannot", "couldn't", "mayn't", "mightn't", "mustn't", "oughtn't", "it's", "that's", "who's",
    "what's", "there's", "here's", "when's", "where's", "why's", "how's", "not", "no", "never",
    "none", "nope", "nothing", "nowhere", "nobody", "notwithstanding", "however", "although", "though", "but",
    "yet", "either", "neither", "nor", "or", "and", "also", "more", "less", "most",
    "least", "very", "too", "so", "such", "just", "only", "quite", "almost", "even",
    "well", "better", "best", "worse", "worst", "moreover", "furthermore", "nevertheless", "nonetheless", "however",
    "therefore", "consequently", "thus", "hence", "since", "because", "although", "though", "if", "unless",
    "until", "while", "when", "where", "after", "before", "because", "since", "if", "unless",
    "until", "while", "when", "where", "after", "before", "if", "unless", "while", "when",
    "where", "after", "before", "though", "although", "because", "since", "while", "when", "where",
    "if", "unless", "until", "though", "although", "because", "since", "so", "that", "if",
    "unless", "until", "while", "when", "where", "after", "before", "if", "unless", "until",
    "while", "when", "where", "after", "before", "but", "and", "or", "as", "if",
    "unless", "until", "while", "when", "where", "after", "before", "but", "and", "or",
    "as", "because", "since", "so", "that", "if", "unless", "until", "though", "although",
    "because", "since", "while", "when", "where", "if", "unless", "until", "though", "although",
    "because", "since", "so", "that", "if", "unless", "until", "though", "although", "because",
    "since", "while", "when", "where", "after", "before", "if", "unless", "until", "though",
    "although", "because", "since", "so", "that", "if", "unless", "until", "while", "when",
    "where", "after", "before", "though", "although", "because", "since", "so", "that", "if",
    "unless", "until", "while", "when", "where", "after", "before", "but", "and", "or",
    "as", "because", "since", "so", "that", "if", "unless", "until", "though", "although",
    "because", "since", "while", "when", "where", "if", "unless", "until", "though", "although",
    "because", "since", "so", "that", "if", "unless", "until", "though", "although", "because"
    ",", "Wa", "--", ";", ":", "...", "-", ".", "?", "!", "'", "#", "``", "`", "$", "US$", "C$", "and", "or",
    "But", "but", "million", "billion", "one", "two", "10", "the", "a", "The", "an", "this", "there", "There",
    "Perestroika", "besuboru", "de", "etc.", "of", "for", "on", "new", "other", "last", "many", "higher", "lower",
    "largest", "least", "latest", "best", "1", "2", "3", "4", "5", "will", "would", "could", "can", "may", "all",
    "such", "half", "Such", "All", "Word", "it", "he", "they", "I", "It", "its", "their", "his", "her", "our",
    "n't", "also", "not", "only", "even", "more", "earlier", "less", "better", "longer", "most", "Most", "up",
    "out", "off", "in", "down", "&", "to", "To", "TO", "OK", "Oh", "no", "watch", "haul", "extinguish", "hold",
    "chill", "eat", "surf", "devour", "drive", "sail", "descend", "glide", "throw", "carry", "dine", "call",
    "soar", "walk", "sip", "rinse", "uncork", "skate", "type", "read", "bake", "poke", "consume", "fly", "fasten",
    "hit", "flush", "peel", "dry", "crave", "ride", "sit", "indulge", "chop", "be", "make", "buy", "take", "said",
    "was", "were", "had", "did", "cooling", "heating", "including", "according", "being", "growing", "trying",
    "been", "expected", "made", "compared", "based", "are", "have", "say", "do", "re", "is", "has", "says", "s",
    "does", "which", "that", "That", "THAT", "who", "what", "What", "whom", "Who", "whose", "when", "where", "how",
    "When", "why",
]

# remove duplicates
non_words = list(set(non_words))

print(len(non_words))
# Out:
# 350

# %%
# force remove words in words from non_words
non_words = list(set(non_words) - set(words))

print(len(non_words))

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert-base-uncased")
model = DistilBertModel.from_pretrained("distilbert-base-uncased")

# %%
# create a function that takes a list of words and returns a list of embeddings
def get_embeddings(words):
    embeddings = []

    for word in words:
        input_ids = torch.tensor(tokenizer.encode(word)).unsqueeze(0)
        outputs = model(input_ids)
        last_hidden_states = outputs[0]
        embeddings.append(torch.mean(last_hidden_states[0][1:-1], dim=0).tolist())
    
    assert len(embeddings) == len(words)
    return embeddings

embeddings = get_embeddings(words)
most_common_embeddings = get_embeddings(most_common_words)
non_embeddings = get_embeddings(non_words)

# %%
# slice the lists into training and test sets
words_train = words[:int(len(words)*0.8)]
words_test = words[int(len(words)*0.8):]
embeddings_train = embeddings[:int(len(embeddings)*0.8)]
embeddings_test = embeddings[int(len(embeddings)*0.8):]

most_common_words_train = most_common_words[:int(len(most_common_words)*0.8)]
most_common_words_test = most_common_words[int(len(most_common_words)*0.8):]
most_common_embeddings_train = most_common_embeddings[:int(len(most_common_embeddings)*0.8)]
most_common_embeddings_test = most_common_embeddings[int(len(most_common_embeddings)*0.8):]

non_words_train = non_words[:int(len(non_words)*0.8)]
non_words_test = non_words[int(len(non_words)*0.8):]
non_embeddings_train = non_embeddings[:int(len(non_embeddings)*0.8)]
non_embeddings_test = non_embeddings[int(len(non_embeddings)*0.8):]

# create a dataframe with the training sets
train_embeddings = embeddings_train + most_common_embeddings_train + non_embeddings_train
df_train = pd.DataFrame(train_embeddings)
# convert the column names to strings
df_train.columns = [str(i) for i in df_train.columns]

df_train['label'] = [1]*len(words_train) + [1]*len(most_common_words_train) + [0]*len(non_words_train)
df_train['word'] = words_train + most_common_words_train + non_words_train

# create a dataframe with the test sets
test_embeddings = embeddings_test + most_common_embeddings_test + non_embeddings_test
df_test = pd.DataFrame(test_embeddings)
# convert the column names to strings
df_test.columns = [str(i) for i in df_test.columns]

df_test['label'] = [1]*len(words_test) + [1]*len(most_common_words_test) + [0]*len(non_words_test)
df_test['word'] = words_test + most_common_words_test + non_words_test

# df_train = pd.DataFrame({
#     'word': words_train + most_common_words_train + non_words_train,
#     'embedding': embeddings_train + most_common_embeddings_train + non_embeddings_train,
#     'label': [1]*len(words_train) + [1]*len(most_common_words_train) + [0]*len(non_words_train)
# })

# df_test = pd.DataFrame({
#     'word': words_test + most_common_words_test + non_words_test,
#     'embedding': embeddings_test + most_common_embeddings_test + non_embeddings_test,
#     'label': [1]*len(words_test) + [1]*len(most_common_words_test) + [0]*len(non_words_test)
# })

# shuffle the dataframes
# df_train = df_train.sample(frac=1).reset_index(drop=True)
# df_test = df_test.sample(frac=1).reset_index(drop=True)

print(df_train[:5])
print(df_train[-5:])
print(df_test[:5])
print(df_test[-5:])
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.374845 -0.251046 -0.046378 -0.120344 -0.020453  0.712524 -0.144484
# 1  0.261447  0.365437 -0.208051 -0.554422  0.199989  0.143858  0.485012
# 2 -0.331599 -0.376078  0.308602 -0.473974 -0.233084  0.613104 -0.108882
# 3  0.193025  0.161425 -0.223975 -0.111447  0.172411  0.328737  0.340810
# 4  0.223298 -0.060303 -0.277992 -0.209905  0.598620  0.201425 -0.036685
#
#           7         8         9  ...       760       761       762       763  \
# 0  0.426953 -0.022439 -0.457561  ...  0.600050 -0.077704 -0.002019 -0.153695
# 1  0.187004 -0.419440 -0.629365  ...  0.420119 -0.217428 -0.018963 -0.023821
# 2  0.348131 -0.161160 -0.042700  ...  0.203100 -0.120749 -0.077259  0.015973
# 3  0.159895  0.332110 -0.769091  ... -0.150431 -0.086227  0.177500  0.135876
# 4 -0.058138 -0.166255 -0.743760  ...  0.367954 -0.164253  0.208860 -0.171945
#
#         764       765       766       767  label    word
# 0  0.148495  0.054825  0.459002 -0.115428      1  person
# 1  0.128539  0.247738  0.552906  0.071565      1    bear
# 2 -0.270267  0.015585 -0.046584  0.316326      1    purr
# 3  0.174943  0.084433  0.190047 -0.163231      1    sink
# 4  0.091896 -0.121467  0.289441  0.275154      1    idea
#
# [5 rows x 770 columns]
#             0         1         2         3         4         5         6  \
# 579 -0.167986 -0.570951  0.101563 -0.353870  0.345035  0.221128 -0.046457
# 580  0.268027  0.155473  0.772552 -0.382267 -0.413270  0.064565  0.495567
# 581 -0.391213  0.093215 -0.206731 -0.531297  0.581816  0.230454  0.063236
# 582 -0.207062 -0.283688  0.094480 -0.357153 -0.030269  0.215456  0.111045
# 583 -0.196553 -0.471490 -0.471903 -0.572765  0.146385 -0.023085  0.112598
#
#             7         8         9  ...       760       761       762  \
# 579  0.682195  0.319933 -0.538745  ...  0.098629  0.006262 -0.378033
# 580 -0.000032 -0.291037 -0.296035  ... -0.138879  0.015295 -0.354068
# 581  0.768897  0.005954 -0.477028  ... -0.303942 -0.279146 -0.202429
# 582  0.209272 -0.394530 -0.390407  ...  0.315936 -0.037034 -0.197256
# 583  0.555810  0.124613 -0.767064  ...  0.334612 -0.036840 -0.050907
#
#           763       764       765       766       767  label   word
# 579 -0.086823 -0.172996  0.035353  0.285326 -0.126027      0   then
# 580 -0.483776  0.246194  0.155290  0.807945  0.234041      0      4
# 581 -0.043938 -0.174045  0.051888  0.194135 -0.146475      0   here
# 582 -0.136761  0.227948  0.226201  0.263620 -0.239210      0  which
# 583 -0.492036  0.168843  0.102299  0.536007  0.001621      0     To
#
# [5 rows x 770 columns]
#           0         1         2         3         4         5         6  \
# 0 -0.106699  0.437826 -0.571758 -0.145886  1.054180  0.520958  0.038175
# 1  0.141818 -0.057983 -0.442358 -0.182030  0.488916  0.086198 -0.034673
# 2  0.031510 -0.000656 -0.098893 -0.132278  0.861081  0.526240  0.190244
# 3 -0.296590  0.342921  0.012009 -0.435406  0.572019  0.275807 -0.332322
# 4 -0.144270  0.622544 -0.311794 -0.299259  0.029563  0.338629  0.099974
#
#           7         8         9  ...       760       761       762       763  \
# 0  0.528610 -0.102807 -0.491627  ...  0.094305 -0.023836  0.450375  0.169282
# 1  0.410475  0.220826 -0.481746  ...  0.697546 -0.088217  0.202779 -0.189614
# 2 -0.053308 -0.254335 -0.636266  ...  0.381931 -0.113179  0.308252  0.223302
# 3  0.109435  0.120233 -0.143129  ...  0.414289 -0.053103  0.404767 -0.143848
# 4  0.255721 -0.246215 -0.697215  ...  0.428494 -0.024149  0.317992  0.029365
#
#         764       765       766       767  label      word
# 0  0.163416  0.256658  0.345096 -0.790029      1     apple
# 1  0.162399 -0.250696  0.522243  0.574230      1    family
# 2 -0.022693  0.253728  0.660273 -0.242501      1     sound
# 3 -0.068329 -0.059116  0.244654 -0.079863      1  keyboard
# 4  0.052694 -0.204114  0.351446 -0.373153      1     anger
#
# [5 rows x 770 columns]
#             0         1         2         3         4         5         6  \
# 142  0.179126 -0.306474  0.256314 -0.412992  0.504344  0.059744  0.079979
# 143 -0.376486 -0.042123 -0.200169 -0.235758  0.457526  0.265557 -0.061170
# 144 -0.375296 -0.108463 -0.230373 -0.304193 -0.139558  0.171729  0.022280
# 145 -0.709177 -0.263273  0.259304 -0.221690  0.279732  0.418621 -0.123388
# 146 -0.139778 -0.350752  0.219195 -0.434375  0.332988 -0.038576  0.143825
#
#             7         8         9  ...       760       761       762  \
# 142 -0.012200 -0.023311 -0.132680  ...  0.276726 -0.226427 -0.035718
# 143  0.974878  0.238283 -0.563133  ...  0.083981 -0.218421 -0.167689
# 144  0.185992  0.273472 -0.637550  ...  0.423004  0.060551 -0.292932
# 145  0.098392 -0.025905 -0.400658  ...  0.437107 -0.010661  0.364930
# 146  0.717982 -0.454648 -0.121658  ... -0.012853 -0.436759 -0.300681
#
#           763       764       765       766       767  label   word
# 142  0.224918  0.205407 -0.021445 -0.013551  0.260104      0   hold
# 143 -0.131774 -0.100006 -0.193804  0.399805 -0.187371      0  There
# 144 -0.303914 -0.008826  0.054869  0.094765  0.284965      0     an
# 145  0.079396 -0.173990  0.016202 -0.085458 -0.010098      0   soft
# 146  0.066171  0.273073 -0.088817  0.377781 -0.144367      0  who's
#
# [5 rows x 770 columns]

# %%
class CustomDataset(Dataset):
    def __init__(self, tokenized_texts, labels):
        self.tokenized_texts = torch.tensor(tokenized_texts)
        self.labels = torch.tensor(labels)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return self.tokenized_texts[idx], self.labels[idx]

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# device = torch.device('mps')
device = torch.device('cpu')

# %%
def create_dataloaders(df_train, df_test):
    train_dataset = CustomDataset(df_train['embedding'], df_train['label'])
    test_dataset = CustomDataset(df_test['embedding'], df_test['label'])

    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

    return train_loader, test_loader

# %%
def train_model(train_loader, input_size):

    # train the model
    net = Net(input_size)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=0.003)

    num_epochs = 100
    net.to(device)

    best_combined_loss = float('inf')

    for epoch in range(num_epochs):
        net.train()
        combined_loss = 0
        for batch in train_loader:
            # get data to GPU if possible
            data = batch[0].to(device=device, dtype=torch.float32)
            if len(data.shape) == 1:
                data = data.unsqueeze(1)
            # data = data.unsqueeze(1)
            targets = batch[1].to(device=device)
            # print(data.shape)
            
            # forward
            scores = net(data)
            loss = criterion(scores, targets)
            combined_loss += loss.item()

            # backward
            optimizer.zero_grad()
            loss.backward()

            # gradient descent or adam step
            optimizer.step()

        if combined_loss < best_combined_loss:
            best_combined_loss = combined_loss
        
        # print initial loss
        # if epoch == 0:
        #     print(f'Initial loss: {combined_loss/len(train_loader)}')
            
        # print average loss per epoch every 10 epochs
        # if (epoch + 1) % 10 == 0:
        #     print(f'Epoch {epoch + 1}, loss={combined_loss/len(train_loader)}')
        #     # print(combined_loss / len(train_loader))

    return net, best_combined_loss

# %%
# evaluate the net using sklearn metrics
def evaluate_net(loader, net):
    y_true = []
    y_pred = []

    net.eval()
    with torch.no_grad():
        for batch in loader:
            # get data to GPU if possible
            data = batch[0].to(device=device, dtype=torch.float32)
            if len(data.shape) == 1:
                data = data.unsqueeze(1)
            # data = data.unsqueeze(1)
            targets = batch[1].to(device=device)

            # forward
            scores = net(data)
            _, predictions = scores.max(1)
            y_true.extend(targets.tolist())
            y_pred.extend(predictions.tolist())

    accuracy = accuracy_score(y_true, y_pred)
    # precision = precision_score(y_true, y_pred)
    # recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    return accuracy, f1
    # return accuracy, precision, recall, f1

# def check_accuracy(loader, net):
#     num_correct = 0
#     num_samples = 0
#     net.eval()

#     with torch.no_grad():
#         for batch in loader:
#             # get data to GPU if possible
#             data = batch[0].to(device=device, dtype=torch.float32)
#             data = data.unsqueeze(1)
#             targets = batch[1].to(device=device)

#             # forward
#             scores = net(data)
#             _, predictions = scores.max(1)
#             num_correct += (predictions == targets).sum()
#             num_samples += predictions.size(0)
    
#     return num_correct / num_samples

# %%
# go through all the slices of the dataframe and train and evaluate the model

all_test_accs = []
all_test_f1s = []
all_combined_losses = []

for slice in range(768):
    print(f'Slice: {slice}')
    # slice = 0

    # create one column slice of the dataframe
    df_train_slice = pd.DataFrame({
        # 'word': df_train['word'],
        'embedding': df_train[str(slice)],
        'label': df_train['label']
    })

    df_test_slice = pd.DataFrame({
        # 'word': df_test['word'],
        'embedding': df_test[str(slice)],
        'label': df_test['label']
    })

    # print(df_train_slice[:5])
    # print(df_train_slice[-5:])

    train_slice_loader, test_slice_loader = create_dataloaders(df_train_slice, df_test_slice)

    # take the best of 3 runs
    best_test_acc = 0
    best_test_f1 = 0

    for i in range(10):
        net, best_combined_loss = train_model(train_slice_loader, 1)

        # train_acc, train_f1 = evaluate_net(train_slice_loader, net)
        test_acc, test_f1 = evaluate_net(test_slice_loader, net)

        if test_acc > best_test_acc and test_f1 > best_test_f1:
            best_test_acc = test_acc
            best_test_f1 = test_f1
            # best_train_acc = train_acc
            # best_net = net
    
    all_test_accs.append(best_test_acc)
    all_test_f1s.append(best_test_f1)
    all_combined_losses.append(best_combined_loss)

    # print(f'Accuracy on training set: {check_accuracy(train_loader, net)*100:.2f}%')
    # print(f'Accuracy on test set: {check_accuracy(test_loader, net)*100:.2f}%')

    print(f'Slice {slice} best combined loss: {best_combined_loss}')
    print(f'Slice {slice} best test f1: {best_test_f1:.4f}')
    print(f'Slice {slice} best test accuracy: {best_test_acc*100:.2f}% \n')

print(len(all_test_accs))
# print(len(all_test_f1s))
# Out:
# Slice: 0
# Slice 0 best combined loss: 24.8671857714653
# Slice 0 best test f1: 0.6667
# Slice 0 best test accuracy: 65.31%
#
# Slice: 1
# Slice 1 best combined loss: 24.007129907608032
# Slice 1 best test f1: 0.7044
# Slice 1 best test accuracy: 68.03%
#
# Slice: 2
# Slice 2 best combined loss: 24.384097695350647
# Slice 2 best test f1: 0.6901
# Slice 2 best test accuracy: 63.95%
#
# Slice: 3
# Slice 3 best combined loss: 24.524148166179657
# Slice 3 best test f1: 0.6386
# Slice 3 best test accuracy: 59.18%
#
# Slice: 4
# Slice 4 best combined loss: 23.788191378116608
# Slice 4 best test f1: 0.7237
# Slice 4 best test accuracy: 71.43%
#
# Slice: 5
# Slice 5 best combined loss: 25.25294041633606
# Slice 5 best test f1: 0.6400
# Slice 5 best test accuracy: 57.14%
#
# Slice: 6
# Slice 6 best combined loss: 25.430784165859222
# Slice 6 best test f1: 0.6667
# Slice 6 best test accuracy: 57.82%
#
# Slice: 7
# Slice 7 best combined loss: 24.669884860515594
# Slice 7 best test f1: 0.6875
# Slice 7 best test accuracy: 65.99%
#
# Slice: 8
# Slice 8 best combined loss: 24.67176777124405
# Slice 8 best test f1: 0.6024
# Slice 8 best test accuracy: 55.10%
#
# Slice: 9
# Slice 9 best combined loss: 25.54203498363495
# Slice 9 best test f1: 0.6570
# Slice 9 best test accuracy: 51.70%
#
# Slice: 10
# Slice 10 best combined loss: 25.45395791530609
# Slice 10 best test f1: 0.6354
# Slice 10 best test accuracy: 52.38%
#
# Slice: 11
# Slice 11 best combined loss: 25.588056981563568
# Slice 11 best test f1: 0.6603
# Slice 11 best test accuracy: 51.70%
#
# Slice: 12
# Slice 12 best combined loss: 24.424385488033295
# Slice 12 best test f1: 0.6784
# Slice 12 best test accuracy: 62.59%
#
# Slice: 13
# Slice 13 best combined loss: 25.597331821918488
# Slice 13 best test f1: 0.6941
# Slice 13 best test accuracy: 54.42%
#
# Slice: 14
# Slice 14 best combined loss: 24.92395916581154
# Slice 14 best test f1: 0.6375
# Slice 14 best test accuracy: 60.54%
#
# Slice: 15
# Slice 15 best combined loss: 25.431296348571777
# Slice 15 best test f1: 0.6292
# Slice 15 best test accuracy: 55.10%
#
# Slice: 16
# Slice 16 best combined loss: 24.5966075360775
# Slice 16 best test f1: 0.5960
# Slice 16 best test accuracy: 58.50%
#
# Slice: 17
# Slice 17 best combined loss: 25.45158940553665
# Slice 17 best test f1: 0.6667
# Slice 17 best test accuracy: 59.86%
#
# Slice: 18
# Slice 18 best combined loss: 25.433910489082336
# Slice 18 best test f1: 0.6146
# Slice 18 best test accuracy: 49.66%
#
# Slice: 19
# Slice 19 best combined loss: 25.29878854751587
# Slice 19 best test f1: 0.5977
# Slice 19 best test accuracy: 52.38%
#
# Slice: 20
# Slice 20 best combined loss: 25.44418102502823
# Slice 20 best test f1: 0.6196
# Slice 20 best test accuracy: 52.38%
#
# Slice: 21
# Slice 21 best combined loss: 24.813971906900406
# Slice 21 best test f1: 0.6705
# Slice 21 best test accuracy: 60.54%
#
# Slice: 22
# Slice 22 best combined loss: 25.569450616836548
# Slice 22 best test f1: 0.7000
# Slice 22 best test accuracy: 59.18%
#
# Slice: 23
# Slice 23 best combined loss: 25.494085609912872
# Slice 23 best test f1: 0.5882
# Slice 23 best test accuracy: 52.38%
#
# Slice: 24
# Slice 24 best combined loss: 25.32294076681137
# Slice 24 best test f1: 0.5150
# Slice 24 best test accuracy: 44.90%
#
# Slice: 25
# Slice 25 best combined loss: 25.51952487230301
# Slice 25 best test f1: 0.6919
# Slice 25 best test accuracy: 61.22%
#
# Slice: 26
# Slice 26 best combined loss: 25.59386795759201
# Slice 26 best test f1: 0.6948
# Slice 26 best test accuracy: 55.78%
#
# Slice: 27
# Slice 27 best combined loss: 19.722629696130753
# Slice 27 best test f1: 0.7602
# Slice 27 best test accuracy: 72.11%
#
# Slice: 28
# Slice 28 best combined loss: 24.41683804988861
# Slice 28 best test f1: 0.5952
# Slice 28 best test accuracy: 53.74%
#
# Slice: 29
# Slice 29 best combined loss: 23.487136244773865
# Slice 29 best test f1: 0.6750
# Slice 29 best test accuracy: 64.63%
#
# Slice: 30
# Slice 30 best combined loss: 25.5433669090271
# Slice 30 best test f1: 0.6800
# Slice 30 best test accuracy: 56.46%
#
# Slice: 31
# Slice 31 best combined loss: 25.387904465198517
# Slice 31 best test f1: 0.5227
# Slice 31 best test accuracy: 42.86%
#
# Slice: 32
# Slice 32 best combined loss: 23.104522168636322
# Slice 32 best test f1: 0.7143
# Slice 32 best test accuracy: 70.07%
#
# Slice: 33
# Slice 33 best combined loss: 24.92217594385147
# Slice 33 best test f1: 0.5976
# Slice 33 best test accuracy: 55.10%
#
# Slice: 34
# Slice 34 best combined loss: 23.899811923503876
# Slice 34 best test f1: 0.7516
# Slice 34 best test accuracy: 73.47%
#
# Slice: 35
# Slice 35 best combined loss: 23.279665142297745
# Slice 35 best test f1: 0.5930
# Slice 35 best test accuracy: 52.38%
#
# Slice: 36
# Slice 36 best combined loss: 24.795271545648575
# Slice 36 best test f1: 0.6552
# Slice 36 best test accuracy: 59.18%
#
# Slice: 37
# Slice 37 best combined loss: 25.30197113752365
# Slice 37 best test f1: 0.6092
# Slice 37 best test accuracy: 53.74%
#
# Slice: 38
# Slice 38 best combined loss: 24.904390037059784
# Slice 38 best test f1: 0.6000
# Slice 38 best test accuracy: 56.46%
#
# Slice: 39
# Slice 39 best combined loss: 25.117791175842285
# Slice 39 best test f1: 0.5309
# Slice 39 best test accuracy: 48.30%
#
# Slice: 40
# Slice 40 best combined loss: 25.38510811328888
# Slice 40 best test f1: 0.5412
# Slice 40 best test accuracy: 46.94%
#
# Slice: 41
# Slice 41 best combined loss: 25.589518129825592
# Slice 41 best test f1: 0.6904
# Slice 41 best test accuracy: 58.50%
#
# Slice: 42
# Slice 42 best combined loss: 25.561194479465485
# Slice 42 best test f1: 0.6571
# Slice 42 best test accuracy: 51.02%
#
# Slice: 43
# Slice 43 best combined loss: 25.227945685386658
# Slice 43 best test f1: 0.5765
# Slice 43 best test accuracy: 51.02%
#
# Slice: 44
# Slice 44 best combined loss: 17.507679864764214
# Slice 44 best test f1: 0.7826
# Slice 44 best test accuracy: 76.19%
#
# Slice: 45
# Slice 45 best combined loss: 25.589146375656128
# Slice 45 best test f1: 0.6697
# Slice 45 best test accuracy: 51.02%
#
# Slice: 46
# Slice 46 best combined loss: 24.44561243057251
# Slice 46 best test f1: 0.7030
# Slice 46 best test accuracy: 66.67%
#
# Slice: 47
# Slice 47 best combined loss: 25.57153695821762
# Slice 47 best test f1: 0.6533
# Slice 47 best test accuracy: 53.06%
#
# Slice: 48
# Slice 48 best combined loss: 22.441568821668625
# Slice 48 best test f1: 0.7625
# Slice 48 best test accuracy: 74.15%
#
# Slice: 49
# Slice 49 best combined loss: 25.488945484161377
# Slice 49 best test f1: 0.6667
# Slice 49 best test accuracy: 58.50%
#
# Slice: 50
# Slice 50 best combined loss: 23.91011819243431
# Slice 50 best test f1: 0.5802
# Slice 50 best test accuracy: 53.74%
#
# Slice: 51
# Slice 51 best combined loss: 24.5942165851593
# Slice 51 best test f1: 0.5912
# Slice 51 best test accuracy: 55.78%
#
# Slice: 52
# Slice 52 best combined loss: 24.884805619716644
# Slice 52 best test f1: 0.6199
# Slice 52 best test accuracy: 55.78%
#
# Slice: 53
# Slice 53 best combined loss: 25.283533215522766
# Slice 53 best test f1: 0.6901
# Slice 53 best test accuracy: 63.95%
#
# Slice: 54
# Slice 54 best combined loss: 25.454164028167725
# Slice 54 best test f1: 0.6433
# Slice 54 best test accuracy: 58.50%
#
# Slice: 55
# Slice 55 best combined loss: 24.21785455942154
# Slice 55 best test f1: 0.6875
# Slice 55 best test accuracy: 65.99%
#
# Slice: 56
# Slice 56 best combined loss: 25.58727526664734
# Slice 56 best test f1: 0.7037
# Slice 56 best test accuracy: 56.46%
#
# Slice: 57
# Slice 57 best combined loss: 25.52965784072876
# Slice 57 best test f1: 0.6042
# Slice 57 best test accuracy: 48.30%
#
# Slice: 58
# Slice 58 best combined loss: 21.47999021410942
# Slice 58 best test f1: 0.7389
# Slice 58 best test accuracy: 72.11%
#
# Slice: 59
# Slice 59 best combined loss: 25.32022112607956
# Slice 59 best test f1: 0.6592
# Slice 59 best test accuracy: 58.50%
#
# Slice: 60
# Slice 60 best combined loss: 25.330224096775055
# Slice 60 best test f1: 0.6704
# Slice 60 best test accuracy: 59.86%
#
# Slice: 61
# Slice 61 best combined loss: 24.370761215686798
# Slice 61 best test f1: 0.6125
# Slice 61 best test accuracy: 57.82%
#
# Slice: 62
# Slice 62 best combined loss: 22.34066766500473
# Slice 62 best test f1: 0.6795
# Slice 62 best test accuracy: 65.99%
#
# Slice: 63
# Slice 63 best combined loss: 24.78693723678589
# Slice 63 best test f1: 0.5200
# Slice 63 best test accuracy: 51.02%
#
# Slice: 64
# Slice 64 best combined loss: 24.788866221904755
# Slice 64 best test f1: 0.6164
# Slice 64 best test accuracy: 58.50%
#
# Slice: 65
# Slice 65 best combined loss: 25.114463925361633
# Slice 65 best test f1: 0.6506
# Slice 65 best test accuracy: 60.54%
#
# Slice: 66
# Slice 66 best combined loss: 25.305132627487183
# Slice 66 best test f1: 0.6628
# Slice 66 best test accuracy: 60.54%
#
# Slice: 67
# Slice 67 best combined loss: 25.603692531585693
# Slice 67 best test f1: 0.6875
# Slice 67 best test accuracy: 52.38%
#
# Slice: 68
# Slice 68 best combined loss: 24.20655131340027
# Slice 68 best test f1: 0.6624
# Slice 68 best test accuracy: 63.95%
#
# Slice: 69
# Slice 69 best combined loss: 25.58782559633255
# Slice 69 best test f1: 0.6887
# Slice 69 best test accuracy: 55.10%
#
# Slice: 70
# Slice 70 best combined loss: 25.05869883298874
# Slice 70 best test f1: 0.6061
# Slice 70 best test accuracy: 55.78%
#
# Slice: 71
# Slice 71 best combined loss: 25.329163193702698
# Slice 71 best test f1: 0.6012
# Slice 71 best test accuracy: 53.06%
#
# Slice: 72
# Slice 72 best combined loss: 24.46744230389595
# Slice 72 best test f1: 0.6784
# Slice 72 best test accuracy: 62.59%
#
# Slice: 73
# Slice 73 best combined loss: 24.99406325817108
# Slice 73 best test f1: 0.5823
# Slice 73 best test accuracy: 55.10%
#
# Slice: 74
# Slice 74 best combined loss: 25.45278662443161
# Slice 74 best test f1: 0.6471
# Slice 74 best test accuracy: 59.18%
#
# Slice: 75
# Slice 75 best combined loss: 25.382377445697784
# Slice 75 best test f1: 0.6235
# Slice 75 best test accuracy: 56.46%
#
# Slice: 76
# Slice 76 best combined loss: 25.592611134052277
# Slice 76 best test f1: 0.6794
# Slice 76 best test accuracy: 54.42%
#
# Slice: 77
# Slice 77 best combined loss: 24.743539571762085
# Slice 77 best test f1: 0.6667
# Slice 77 best test accuracy: 60.54%
#
# Slice: 78
# Slice 78 best combined loss: 25.607197046279907
# Slice 78 best test f1: 0.6875
# Slice 78 best test accuracy: 52.38%
#
# Slice: 79
# Slice 79 best combined loss: 25.48216551542282
# Slice 79 best test f1: 0.6354
# Slice 79 best test accuracy: 52.38%
#
# Slice: 80
# Slice 80 best combined loss: 25.53010642528534
# Slice 80 best test f1: 0.6138
# Slice 80 best test accuracy: 50.34%
#
# Slice: 81
# Slice 81 best combined loss: 25.48445451259613
# Slice 81 best test f1: 0.6851
# Slice 81 best test accuracy: 61.22%
#
# Slice: 82
# Slice 82 best combined loss: 25.17428421974182
# Slice 82 best test f1: 0.5862
# Slice 82 best test accuracy: 51.02%
#
# Slice: 83
# Slice 83 best combined loss: 24.77487999200821
# Slice 83 best test f1: 0.6626
# Slice 83 best test accuracy: 62.59%
#
# Slice: 84
# Slice 84 best combined loss: 25.607943415641785
# Slice 84 best test f1: 0.6875
# Slice 84 best test accuracy: 52.38%
#
# Slice: 85
# Slice 85 best combined loss: 22.201289027929306
# Slice 85 best test f1: 0.7059
# Slice 85 best test accuracy: 69.39%
#
# Slice: 86
# Slice 86 best combined loss: 25.32807755470276
# Slice 86 best test f1: 0.6826
# Slice 86 best test accuracy: 63.95%
#
# Slice: 87
# Slice 87 best combined loss: 25.59025901556015
# Slice 87 best test f1: 0.6909
# Slice 87 best test accuracy: 53.74%
#
# Slice: 88
# Slice 88 best combined loss: 25.003982841968536
# Slice 88 best test f1: 0.5988
# Slice 88 best test accuracy: 54.42%
#
# Slice: 89
# Slice 89 best combined loss: 25.27552479505539
# Slice 89 best test f1: 0.6272
# Slice 89 best test accuracy: 57.14%
#
# Slice: 90
# Slice 90 best combined loss: 25.122242629528046
# Slice 90 best test f1: 0.6707
# Slice 90 best test accuracy: 62.59%
#
# Slice: 91
# Slice 91 best combined loss: 25.38293159008026
# Slice 91 best test f1: 0.6509
# Slice 91 best test accuracy: 59.86%
#
# Slice: 92
# Slice 92 best combined loss: 25.494482100009918
# Slice 92 best test f1: 0.5978
# Slice 92 best test accuracy: 49.66%
#
# Slice: 93
# Slice 93 best combined loss: 24.01425066590309
# Slice 93 best test f1: 0.6289
# Slice 93 best test accuracy: 59.86%
#
# Slice: 94
# Slice 94 best combined loss: 23.895366430282593
# Slice 94 best test f1: 0.6463
# Slice 94 best test accuracy: 60.54%
#
# Slice: 95
# Slice 95 best combined loss: 25.527760326862335
# Slice 95 best test f1: 0.6769
# Slice 95 best test accuracy: 57.14%
#
# Slice: 96
# Slice 96 best combined loss: 23.91862228512764
# Slice 96 best test f1: 0.6420
# Slice 96 best test accuracy: 60.54%
#
# Slice: 97
# Slice 97 best combined loss: 25.566894590854645
# Slice 97 best test f1: 0.6602
# Slice 97 best test accuracy: 52.38%
#
# Slice: 98
# Slice 98 best combined loss: 25.28979068994522
# Slice 98 best test f1: 0.5967
# Slice 98 best test accuracy: 50.34%
#
# Slice: 99
# Slice 99 best combined loss: 24.666250467300415
# Slice 99 best test f1: 0.6509
# Slice 99 best test accuracy: 59.86%
#
# Slice: 100
# Slice 100 best combined loss: 25.465858161449432
# Slice 100 best test f1: 0.6327
# Slice 100 best test accuracy: 51.02%
#
# Slice: 101
# Slice 101 best combined loss: 22.39527153968811
# Slice 101 best test f1: 0.6839
# Slice 101 best test accuracy: 66.67%
#
# Slice: 102
# Slice 102 best combined loss: 24.570423543453217
# Slice 102 best test f1: 0.6707
# Slice 102 best test accuracy: 63.27%
#
# Slice: 103
# Slice 103 best combined loss: 24.891439020633698
# Slice 103 best test f1: 0.6061
# Slice 103 best test accuracy: 55.78%
#
# Slice: 104
# Slice 104 best combined loss: 24.648750066757202
# Slice 104 best test f1: 0.6584
# Slice 104 best test accuracy: 62.59%
#
# Slice: 105
# Slice 105 best combined loss: 25.48634684085846
# Slice 105 best test f1: 0.5730
# Slice 105 best test accuracy: 46.26%
#
# Slice: 106
# Slice 106 best combined loss: 25.480769097805023
# Slice 106 best test f1: 0.5876
# Slice 106 best test accuracy: 50.34%
#
# Slice: 107
# Slice 107 best combined loss: 23.718781173229218
# Slice 107 best test f1: 0.6584
# Slice 107 best test accuracy: 62.59%
#
# Slice: 108
# Slice 108 best combined loss: 25.445098519325256
# Slice 108 best test f1: 0.6556
# Slice 108 best test accuracy: 57.82%
#
# Slice: 109
# Slice 109 best combined loss: 25.547141015529633
# Slice 109 best test f1: 0.5775
# Slice 109 best test accuracy: 46.26%
#
# Slice: 110
# Slice 110 best combined loss: 25.554593443870544
# Slice 110 best test f1: 0.6200
# Slice 110 best test accuracy: 48.30%
#
# Slice: 111
# Slice 111 best combined loss: 25.590028643608093
# Slice 111 best test f1: 0.6944
# Slice 111 best test accuracy: 55.10%
#
# Slice: 112
# Slice 112 best combined loss: 25.511832177639008
# Slice 112 best test f1: 0.6566
# Slice 112 best test accuracy: 53.74%
#
# Slice: 113
# Slice 113 best combined loss: 22.732795029878616
# Slice 113 best test f1: 0.7013
# Slice 113 best test accuracy: 68.71%
#
# Slice: 114
# Slice 114 best combined loss: 25.467397212982178
# Slice 114 best test f1: 0.6512
# Slice 114 best test accuracy: 59.18%
#
# Slice: 115
# Slice 115 best combined loss: 21.99030178785324
# Slice 115 best test f1: 0.7375
# Slice 115 best test accuracy: 71.43%
#
# Slice: 116
# Slice 116 best combined loss: 23.68399938941002
# Slice 116 best test f1: 0.7168
# Slice 116 best test accuracy: 66.67%
#
# Slice: 117
# Slice 117 best combined loss: 25.569386959075928
# Slice 117 best test f1: 0.6860
# Slice 117 best test accuracy: 55.78%
#
# Slice: 118
# Slice 118 best combined loss: 25.423985302448273
# Slice 118 best test f1: 0.6333
# Slice 118 best test accuracy: 55.10%
#
# Slice: 119
# Slice 119 best combined loss: 25.35920375585556
# Slice 119 best test f1: 0.5868
# Slice 119 best test accuracy: 53.06%
#
# Slice: 120
# Slice 120 best combined loss: 24.39973020553589
# Slice 120 best test f1: 0.6065
# Slice 120 best test accuracy: 58.50%
#
# Slice: 121
# Slice 121 best combined loss: 25.55051952600479
# Slice 121 best test f1: 0.6567
# Slice 121 best test accuracy: 53.06%
#
# Slice: 122
# Slice 122 best combined loss: 24.23724001646042
# Slice 122 best test f1: 0.7018
# Slice 122 best test accuracy: 65.31%
#
# Slice: 123
# Slice 123 best combined loss: 25.230763137340546
# Slice 123 best test f1: 0.6829
# Slice 123 best test accuracy: 64.63%
#
# Slice: 124
# Slice 124 best combined loss: 23.71948030591011
# Slice 124 best test f1: 0.6164
# Slice 124 best test accuracy: 58.50%
#
# Slice: 125
# Slice 125 best combined loss: 25.451750338077545
# Slice 125 best test f1: 0.7283
# Slice 125 best test accuracy: 65.99%
#
# Slice: 126
# Slice 126 best combined loss: 24.90578255057335
# Slice 126 best test f1: 0.5890
# Slice 126 best test accuracy: 54.42%
#
# Slice: 127
# Slice 127 best combined loss: 25.314493119716644
# Slice 127 best test f1: 0.6054
# Slice 127 best test accuracy: 50.34%
#
# Slice: 128
# Slice 128 best combined loss: 24.03484046459198
# Slice 128 best test f1: 0.6000
# Slice 128 best test accuracy: 56.46%
#
# Slice: 129
# Slice 129 best combined loss: 24.67862632870674
# Slice 129 best test f1: 0.6424
# Slice 129 best test accuracy: 59.86%
#
# Slice: 130
# Slice 130 best combined loss: 25.540450513362885
# Slice 130 best test f1: 0.6561
# Slice 130 best test accuracy: 55.78%
#
# Slice: 131
# Slice 131 best combined loss: 22.908641129732132
# Slice 131 best test f1: 0.6624
# Slice 131 best test accuracy: 63.95%
#
# Slice: 132
# Slice 132 best combined loss: 23.40440660715103
# Slice 132 best test f1: 0.6784
# Slice 132 best test accuracy: 62.59%
#
# Slice: 133
# Slice 133 best combined loss: 25.401219189167023
# Slice 133 best test f1: 0.6286
# Slice 133 best test accuracy: 55.78%
#
# Slice: 134
# Slice 134 best combined loss: 24.81595778465271
# Slice 134 best test f1: 0.6585
# Slice 134 best test accuracy: 61.90%
#
# Slice: 135
# Slice 135 best combined loss: 25.069817304611206
# Slice 135 best test f1: 0.6585
# Slice 135 best test accuracy: 61.90%
#
# Slice: 136
# Slice 136 best combined loss: 23.84255051612854
# Slice 136 best test f1: 0.5385
# Slice 136 best test accuracy: 51.02%
#
# Slice: 137
# Slice 137 best combined loss: 25.393234312534332
# Slice 137 best test f1: 0.6561
# Slice 137 best test accuracy: 55.78%
#
# Slice: 138
# Slice 138 best combined loss: 25.284710109233856
# Slice 138 best test f1: 0.5576
# Slice 138 best test accuracy: 50.34%
#
# Slice: 139
# Slice 139 best combined loss: 23.579198598861694
# Slice 139 best test f1: 0.6506
# Slice 139 best test accuracy: 60.54%
#
# Slice: 140
# Slice 140 best combined loss: 24.912708282470703
# Slice 140 best test f1: 0.6746
# Slice 140 best test accuracy: 62.59%
#
# Slice: 141
# Slice 141 best combined loss: 25.480063498020172
# Slice 141 best test f1: 0.5862
# Slice 141 best test accuracy: 51.02%
#
# Slice: 142
# Slice 142 best combined loss: 22.503656268119812
# Slice 142 best test f1: 0.6364
# Slice 142 best test accuracy: 61.90%
#
# Slice: 143
# Slice 143 best combined loss: 24.464246839284897
# Slice 143 best test f1: 0.7273
# Slice 143 best test accuracy: 67.35%
#
# Slice: 144
# Slice 144 best combined loss: 25.48658949136734
# Slice 144 best test f1: 0.5714
# Slice 144 best test accuracy: 46.94%
#
# Slice: 145
# Slice 145 best combined loss: 24.691345244646072
# Slice 145 best test f1: 0.6184
# Slice 145 best test accuracy: 60.54%
#
# Slice: 146
# Slice 146 best combined loss: 25.498687744140625
# Slice 146 best test f1: 0.6333
# Slice 146 best test accuracy: 55.10%
#
# Slice: 147
# Slice 147 best combined loss: 23.763615548610687
# Slice 147 best test f1: 0.7013
# Slice 147 best test accuracy: 68.71%
#
# Slice: 148
# Slice 148 best combined loss: 24.08759182691574
# Slice 148 best test f1: 0.6879
# Slice 148 best test accuracy: 66.67%
#
# Slice: 149
# Slice 149 best combined loss: 25.57450360059738
# Slice 149 best test f1: 0.6570
# Slice 149 best test accuracy: 51.70%
#
# Slice: 150
# Slice 150 best combined loss: 25.601449131965637
# Slice 150 best test f1: 0.6875
# Slice 150 best test accuracy: 52.38%
#
# Slice: 151
# Slice 151 best combined loss: 25.509920179843903
# Slice 151 best test f1: 0.6557
# Slice 151 best test accuracy: 57.14%
#
# Slice: 152
# Slice 152 best combined loss: 24.402538925409317
# Slice 152 best test f1: 0.7081
# Slice 152 best test accuracy: 68.03%
#
# Slice: 153
# Slice 153 best combined loss: 25.601092219352722
# Slice 153 best test f1: 0.6875
# Slice 153 best test accuracy: 52.38%
#
# Slice: 154
# Slice 154 best combined loss: 24.6625035405159
# Slice 154 best test f1: 0.7030
# Slice 154 best test accuracy: 66.67%
#
# Slice: 155
# Slice 155 best combined loss: 25.333797693252563
# Slice 155 best test f1: 0.6400
# Slice 155 best test accuracy: 57.14%
#
# Slice: 156
# Slice 156 best combined loss: 25.536571443080902
# Slice 156 best test f1: 0.6736
# Slice 156 best test accuracy: 57.14%
#
# Slice: 157
# Slice 157 best combined loss: 25.334093749523163
# Slice 157 best test f1: 0.6552
# Slice 157 best test accuracy: 59.18%
#
# Slice: 158
# Slice 158 best combined loss: 25.495307326316833
# Slice 158 best test f1: 0.6863
# Slice 158 best test accuracy: 56.46%
#
# Slice: 159
# Slice 159 best combined loss: 22.77476954460144
# Slice 159 best test f1: 0.6375
# Slice 159 best test accuracy: 60.54%
#
# Slice: 160
# Slice 160 best combined loss: 25.057700037956238
# Slice 160 best test f1: 0.5714
# Slice 160 best test accuracy: 53.06%
#
# Slice: 161
# Slice 161 best combined loss: 24.08897429704666
# Slice 161 best test f1: 0.6750
# Slice 161 best test accuracy: 64.63%
#
# Slice: 162
# Slice 162 best combined loss: 25.10650932788849
# Slice 162 best test f1: 0.6587
# Slice 162 best test accuracy: 61.22%
#
# Slice: 163
# Slice 163 best combined loss: 25.482981383800507
# Slice 163 best test f1: 0.6424
# Slice 163 best test accuracy: 59.86%
#
# Slice: 164
# Slice 164 best combined loss: 25.425205171108246
# Slice 164 best test f1: 0.6102
# Slice 164 best test accuracy: 53.06%
#
# Slice: 165
# Slice 165 best combined loss: 25.10090535879135
# Slice 165 best test f1: 0.6211
# Slice 165 best test accuracy: 58.50%
#
# Slice: 166
# Slice 166 best combined loss: 25.600695490837097
# Slice 166 best test f1: 0.6875
# Slice 166 best test accuracy: 52.38%
#
# Slice: 167
# Slice 167 best combined loss: 23.091629594564438
# Slice 167 best test f1: 0.6341
# Slice 167 best test accuracy: 59.18%
#
# Slice: 168
# Slice 168 best combined loss: 23.914869040250778
# Slice 168 best test f1: 0.7574
# Slice 168 best test accuracy: 72.11%
#
# Slice: 169
# Slice 169 best combined loss: 23.634637385606766
# Slice 169 best test f1: 0.6282
# Slice 169 best test accuracy: 60.54%
#
# Slice: 170
# Slice 170 best combined loss: 23.63086235523224
# Slice 170 best test f1: 0.6203
# Slice 170 best test accuracy: 59.18%
#
# Slice: 171
# Slice 171 best combined loss: 24.846716105937958
# Slice 171 best test f1: 0.6182
# Slice 171 best test accuracy: 57.14%
#
# Slice: 172
# Slice 172 best combined loss: 21.43343511223793
# Slice 172 best test f1: 0.7081
# Slice 172 best test accuracy: 68.03%
#
# Slice: 173
# Slice 173 best combined loss: 25.595662713050842
# Slice 173 best test f1: 0.6816
# Slice 173 best test accuracy: 51.70%
#
# Slice: 174
# Slice 174 best combined loss: 25.53671646118164
# Slice 174 best test f1: 0.6237
# Slice 174 best test accuracy: 52.38%
#
# Slice: 175
# Slice 175 best combined loss: 24.496295154094696
# Slice 175 best test f1: 0.6310
# Slice 175 best test accuracy: 57.82%
#
# Slice: 176
# Slice 176 best combined loss: 25.35327023267746
# Slice 176 best test f1: 0.6743
# Slice 176 best test accuracy: 61.22%
#
# Slice: 177
# Slice 177 best combined loss: 24.650908708572388
# Slice 177 best test f1: 0.6163
# Slice 177 best test accuracy: 55.10%
#
# Slice: 178
# Slice 178 best combined loss: 25.04739886522293
# Slice 178 best test f1: 0.5843
# Slice 178 best test accuracy: 49.66%
#
# Slice: 179
# Slice 179 best combined loss: 25.559867918491364
# Slice 179 best test f1: 0.7094
# Slice 179 best test accuracy: 59.86%
#
# Slice: 180
# Slice 180 best combined loss: 25.25578933954239
# Slice 180 best test f1: 0.6802
# Slice 180 best test accuracy: 57.14%
#
# Slice: 181
# Slice 181 best combined loss: 25.1781245470047
# Slice 181 best test f1: 0.6235
# Slice 181 best test accuracy: 56.46%
#
# Slice: 182
# Slice 182 best combined loss: 25.56630164384842
# Slice 182 best test f1: 0.6346
# Slice 182 best test accuracy: 48.30%
#
# Slice: 183
# Slice 183 best combined loss: 25.413552224636078
# Slice 183 best test f1: 0.6882
# Slice 183 best test accuracy: 60.54%
#
# Slice: 184
# Slice 184 best combined loss: 25.598978400230408
# Slice 184 best test f1: 0.6957
# Slice 184 best test accuracy: 57.14%
#
# Slice: 185
# Slice 185 best combined loss: 25.448999881744385
# Slice 185 best test f1: 0.6077
# Slice 185 best test accuracy: 51.70%
#
# Slice: 186
# Slice 186 best combined loss: 25.598715245723724
# Slice 186 best test f1: 0.6512
# Slice 186 best test accuracy: 48.98%
#
# Slice: 187
# Slice 187 best combined loss: 24.880774557590485
# Slice 187 best test f1: 0.6786
# Slice 187 best test accuracy: 63.27%
#
# Slice: 188
# Slice 188 best combined loss: 23.445751667022705
# Slice 188 best test f1: 0.6133
# Slice 188 best test accuracy: 60.54%
#
# Slice: 189
# Slice 189 best combined loss: 24.47074729204178
# Slice 189 best test f1: 0.6897
# Slice 189 best test accuracy: 63.27%
#
# Slice: 190
# Slice 190 best combined loss: 25.534147143363953
# Slice 190 best test f1: 0.6528
# Slice 190 best test accuracy: 54.42%
#
# Slice: 191
# Slice 191 best combined loss: 24.937373757362366
# Slice 191 best test f1: 0.6012
# Slice 191 best test accuracy: 53.06%
#
# Slice: 192
# Slice 192 best combined loss: 24.925550401210785
# Slice 192 best test f1: 0.6184
# Slice 192 best test accuracy: 60.54%
#
# Slice: 193
# Slice 193 best combined loss: 25.575061082839966
# Slice 193 best test f1: 0.6766
# Slice 193 best test accuracy: 55.78%
#
# Slice: 194
# Slice 194 best combined loss: 23.799959927797318
# Slice 194 best test f1: 0.6994
# Slice 194 best test accuracy: 66.67%
#
# Slice: 195
# Slice 195 best combined loss: 25.605068027973175
# Slice 195 best test f1: 0.6937
# Slice 195 best test accuracy: 53.74%
#
# Slice: 196
# Slice 196 best combined loss: 25.52808105945587
# Slice 196 best test f1: 0.6364
# Slice 196 best test accuracy: 51.02%
#
# Slice: 197
# Slice 197 best combined loss: 25.422061681747437
# Slice 197 best test f1: 0.5930
# Slice 197 best test accuracy: 52.38%
#
# Slice: 198
# Slice 198 best combined loss: 25.589085638523102
# Slice 198 best test f1: 0.7053
# Slice 198 best test accuracy: 58.50%
#
# Slice: 199
# Slice 199 best combined loss: 25.159614861011505
# Slice 199 best test f1: 0.6628
# Slice 199 best test accuracy: 60.54%
#
# Slice: 200
# Slice 200 best combined loss: 22.209989309310913
# Slice 200 best test f1: 0.7394
# Slice 200 best test accuracy: 70.75%
#
# Slice: 201
# Slice 201 best combined loss: 25.574567914009094
# Slice 201 best test f1: 0.6337
# Slice 201 best test accuracy: 49.66%
#
# Slice: 202
# Slice 202 best combined loss: 25.533116102218628
# Slice 202 best test f1: 0.6593
# Slice 202 best test accuracy: 57.82%
#
# Slice: 203
# Slice 203 best combined loss: 25.38306826353073
# Slice 203 best test f1: 0.5349
# Slice 203 best test accuracy: 45.58%
#
# Slice: 204
# Slice 204 best combined loss: 24.667302548885345
# Slice 204 best test f1: 0.6474
# Slice 204 best test accuracy: 58.50%
#
# Slice: 205
# Slice 205 best combined loss: 24.642275899648666
# Slice 205 best test f1: 0.6864
# Slice 205 best test accuracy: 63.95%
#
# Slice: 206
# Slice 206 best combined loss: 25.417419016361237
# Slice 206 best test f1: 0.6885
# Slice 206 best test accuracy: 61.22%
#
# Slice: 207
# Slice 207 best combined loss: 25.571961402893066
# Slice 207 best test f1: 0.6829
# Slice 207 best test accuracy: 55.78%
#
# Slice: 208
# Slice 208 best combined loss: 25.60324192047119
# Slice 208 best test f1: 0.6875
# Slice 208 best test accuracy: 52.38%
#
# Slice: 209
# Slice 209 best combined loss: 24.938200175762177
# Slice 209 best test f1: 0.6310
# Slice 209 best test accuracy: 57.82%
#
# Slice: 210
# Slice 210 best combined loss: 25.464885413646698
# Slice 210 best test f1: 0.6845
# Slice 210 best test accuracy: 59.86%
#
# Slice: 211
# Slice 211 best combined loss: 23.067530632019043
# Slice 211 best test f1: 0.6790
# Slice 211 best test accuracy: 64.63%
#
# Slice: 212
# Slice 212 best combined loss: 25.538413763046265
# Slice 212 best test f1: 0.6011
# Slice 212 best test accuracy: 50.34%
#
# Slice: 213
# Slice 213 best combined loss: 24.98109382390976
# Slice 213 best test f1: 0.6199
# Slice 213 best test accuracy: 55.78%
#
# Slice: 214
# Slice 214 best combined loss: 25.609662294387817
# Slice 214 best test f1: 0.6875
# Slice 214 best test accuracy: 52.38%
#
# Slice: 215
# Slice 215 best combined loss: 20.974690437316895
# Slice 215 best test f1: 0.7919
# Slice 215 best test accuracy: 78.91%
#
# Slice: 216
# Slice 216 best combined loss: 24.851668149232864
# Slice 216 best test f1: 0.6289
# Slice 216 best test accuracy: 59.86%
#
# Slice: 217
# Slice 217 best combined loss: 24.187866985797882
# Slice 217 best test f1: 0.6667
# Slice 217 best test accuracy: 65.99%
#
# Slice: 218
# Slice 218 best combined loss: 25.54303801059723
# Slice 218 best test f1: 0.6734
# Slice 218 best test accuracy: 55.78%
#
# Slice: 219
# Slice 219 best combined loss: 24.88473927974701
# Slice 219 best test f1: 0.6444
# Slice 219 best test accuracy: 56.46%
#
# Slice: 220
# Slice 220 best combined loss: 24.759339153766632
# Slice 220 best test f1: 0.5677
# Slice 220 best test accuracy: 54.42%
#
# Slice: 221
# Slice 221 best combined loss: 23.981289714574814
# Slice 221 best test f1: 0.6375
# Slice 221 best test accuracy: 60.54%
#
# Slice: 222
# Slice 222 best combined loss: 25.445095777511597
# Slice 222 best test f1: 0.6364
# Slice 222 best test accuracy: 56.46%
#
# Slice: 223
# Slice 223 best combined loss: 25.574521839618683
# Slice 223 best test f1: 0.7030
# Slice 223 best test accuracy: 59.18%
#
# Slice: 224
# Slice 224 best combined loss: 25.25041300058365
# Slice 224 best test f1: 0.6971
# Slice 224 best test accuracy: 63.95%
#
# Slice: 225
# Slice 225 best combined loss: 22.563707530498505
# Slice 225 best test f1: 0.7134
# Slice 225 best test accuracy: 69.39%
#
# Slice: 226
# Slice 226 best combined loss: 25.601415395736694
# Slice 226 best test f1: 0.6875
# Slice 226 best test accuracy: 52.38%
#
# Slice: 227
# Slice 227 best combined loss: 22.784362763166428
# Slice 227 best test f1: 0.6267
# Slice 227 best test accuracy: 61.90%
#
# Slice: 228
# Slice 228 best combined loss: 25.39578676223755
# Slice 228 best test f1: 0.6480
# Slice 228 best test accuracy: 57.14%
#
# Slice: 229
# Slice 229 best combined loss: 25.080880999565125
# Slice 229 best test f1: 0.5587
# Slice 229 best test accuracy: 46.26%
#
# Slice: 230
# Slice 230 best combined loss: 22.92084014415741
# Slice 230 best test f1: 0.7117
# Slice 230 best test accuracy: 68.03%
#
# Slice: 231
# Slice 231 best combined loss: 25.542140424251556
# Slice 231 best test f1: 0.6305
# Slice 231 best test accuracy: 48.98%
#
# Slice: 232
# Slice 232 best combined loss: 25.566418766975403
# Slice 232 best test f1: 0.6300
# Slice 232 best test accuracy: 49.66%
#
# Slice: 233
# Slice 233 best combined loss: 24.141393721103668
# Slice 233 best test f1: 0.7168
# Slice 233 best test accuracy: 66.67%
#
# Slice: 234
# Slice 234 best combined loss: 24.949946761131287
# Slice 234 best test f1: 0.6400
# Slice 234 best test accuracy: 57.14%
#
# Slice: 235
# Slice 235 best combined loss: 25.030620515346527
# Slice 235 best test f1: 0.5732
# Slice 235 best test accuracy: 54.42%
#
# Slice: 236
# Slice 236 best combined loss: 25.488055765628815
# Slice 236 best test f1: 0.6270
# Slice 236 best test accuracy: 53.06%
#
# Slice: 237
# Slice 237 best combined loss: 25.600372195243835
# Slice 237 best test f1: 0.6875
# Slice 237 best test accuracy: 52.38%
#
# Slice: 238
# Slice 238 best combined loss: 25.410887122154236
# Slice 238 best test f1: 0.6264
# Slice 238 best test accuracy: 53.74%
#
# Slice: 239
# Slice 239 best combined loss: 24.616543650627136
# Slice 239 best test f1: 0.5875
# Slice 239 best test accuracy: 55.10%
#
# Slice: 240
# Slice 240 best combined loss: 25.584369957447052
# Slice 240 best test f1: 0.6887
# Slice 240 best test accuracy: 55.10%
#
# Slice: 241
# Slice 241 best combined loss: 23.249671757221222
# Slice 241 best test f1: 0.6203
# Slice 241 best test accuracy: 59.18%
#
# Slice: 242
# Slice 242 best combined loss: 24.277739822864532
# Slice 242 best test f1: 0.6258
# Slice 242 best test accuracy: 58.50%
#
# Slice: 243
# Slice 243 best combined loss: 25.394913375377655
# Slice 243 best test f1: 0.6509
# Slice 243 best test accuracy: 59.86%
#
# Slice: 244
# Slice 244 best combined loss: 25.041670262813568
# Slice 244 best test f1: 0.6190
# Slice 244 best test accuracy: 56.46%
#
# Slice: 245
# Slice 245 best combined loss: 24.740072309970856
# Slice 245 best test f1: 0.6854
# Slice 245 best test accuracy: 61.90%
#
# Slice: 246
# Slice 246 best combined loss: 24.02864897251129
# Slice 246 best test f1: 0.6447
# Slice 246 best test accuracy: 63.27%
#
# Slice: 247
# Slice 247 best combined loss: 23.77787685394287
# Slice 247 best test f1: 0.6133
# Slice 247 best test accuracy: 60.54%
#
# Slice: 248
# Slice 248 best combined loss: 23.517643243074417
# Slice 248 best test f1: 0.6705
# Slice 248 best test accuracy: 61.22%
#
# Slice: 249
# Slice 249 best combined loss: 25.53058910369873
# Slice 249 best test f1: 0.6298
# Slice 249 best test accuracy: 54.42%
#
# Slice: 250
# Slice 250 best combined loss: 25.575400173664093
# Slice 250 best test f1: 0.6634
# Slice 250 best test accuracy: 53.74%
#
# Slice: 251
# Slice 251 best combined loss: 22.945272237062454
# Slice 251 best test f1: 0.7125
# Slice 251 best test accuracy: 68.71%
#
# Slice: 252
# Slice 252 best combined loss: 24.134561866521835
# Slice 252 best test f1: 0.7108
# Slice 252 best test accuracy: 67.35%
#
# Slice: 253
# Slice 253 best combined loss: 24.820361375808716
# Slice 253 best test f1: 0.6173
# Slice 253 best test accuracy: 57.82%
#
# Slice: 254
# Slice 254 best combined loss: 25.599420368671417
# Slice 254 best test f1: 0.6875
# Slice 254 best test accuracy: 52.38%
#
# Slice: 255
# Slice 255 best combined loss: 24.542006015777588
# Slice 255 best test f1: 0.6509
# Slice 255 best test accuracy: 59.86%
#
# Slice: 256
# Slice 256 best combined loss: 24.516533941030502
# Slice 256 best test f1: 0.6429
# Slice 256 best test accuracy: 59.18%
#
# Slice: 257
# Slice 257 best combined loss: 25.05642580986023
# Slice 257 best test f1: 0.5930
# Slice 257 best test accuracy: 52.38%
#
# Slice: 258
# Slice 258 best combined loss: 22.57309180498123
# Slice 258 best test f1: 0.6500
# Slice 258 best test accuracy: 61.90%
#
# Slice: 259
# Slice 259 best combined loss: 24.378394961357117
# Slice 259 best test f1: 0.6826
# Slice 259 best test accuracy: 63.95%
#
# Slice: 260
# Slice 260 best combined loss: 25.60872393846512
# Slice 260 best test f1: 0.6875
# Slice 260 best test accuracy: 52.38%
#
# Slice: 261
# Slice 261 best combined loss: 25.40434169769287
# Slice 261 best test f1: 0.6597
# Slice 261 best test accuracy: 55.78%
#
# Slice: 262
# Slice 262 best combined loss: 25.165954887866974
# Slice 262 best test f1: 0.5818
# Slice 262 best test accuracy: 53.06%
#
# Slice: 263
# Slice 263 best combined loss: 25.593708336353302
# Slice 263 best test f1: 0.6937
# Slice 263 best test accuracy: 53.74%
#
# Slice: 264
# Slice 264 best combined loss: 23.755906015634537
# Slice 264 best test f1: 0.7073
# Slice 264 best test accuracy: 67.35%
#
# Slice: 265
# Slice 265 best combined loss: 25.598063468933105
# Slice 265 best test f1: 0.6878
# Slice 265 best test accuracy: 53.06%
#
# Slice: 266
# Slice 266 best combined loss: 25.47483265399933
# Slice 266 best test f1: 0.6250
# Slice 266 best test accuracy: 55.10%
#
# Slice: 267
# Slice 267 best combined loss: 23.990420401096344
# Slice 267 best test f1: 0.6744
# Slice 267 best test accuracy: 61.90%
#
# Slice: 268
# Slice 268 best combined loss: 25.60377126932144
# Slice 268 best test f1: 0.6875
# Slice 268 best test accuracy: 52.38%
#
# Slice: 269
# Slice 269 best combined loss: 25.16353541612625
# Slice 269 best test f1: 0.6316
# Slice 269 best test accuracy: 57.14%
#
# Slice: 270
# Slice 270 best combined loss: 24.096258133649826
# Slice 270 best test f1: 0.6053
# Slice 270 best test accuracy: 59.18%
#
# Slice: 271
# Slice 271 best combined loss: 24.301231563091278
# Slice 271 best test f1: 0.6667
# Slice 271 best test accuracy: 62.59%
#
# Slice: 272
# Slice 272 best combined loss: 25.581410706043243
# Slice 272 best test f1: 0.6842
# Slice 272 best test accuracy: 59.18%
#
# Slice: 273
# Slice 273 best combined loss: 24.618946373462677
# Slice 273 best test f1: 0.6049
# Slice 273 best test accuracy: 56.46%
#
# Slice: 274
# Slice 274 best combined loss: 25.5317462682724
# Slice 274 best test f1: 0.6497
# Slice 274 best test accuracy: 53.06%
#
# Slice: 275
# Slice 275 best combined loss: 25.311242938041687
# Slice 275 best test f1: 0.5309
# Slice 275 best test accuracy: 48.30%
#
# Slice: 276
# Slice 276 best combined loss: 25.46216344833374
# Slice 276 best test f1: 0.7187
# Slice 276 best test accuracy: 63.27%
#
# Slice: 277
# Slice 277 best combined loss: 25.467482924461365
# Slice 277 best test f1: 0.5650
# Slice 277 best test accuracy: 47.62%
#
# Slice: 278
# Slice 278 best combined loss: 24.771097004413605
# Slice 278 best test f1: 0.5212
# Slice 278 best test accuracy: 46.26%
#
# Slice: 279
# Slice 279 best combined loss: 25.404209852218628
# Slice 279 best test f1: 0.6207
# Slice 279 best test accuracy: 55.10%
#
# Slice: 280
# Slice 280 best combined loss: 25.553547084331512
# Slice 280 best test f1: 0.6634
# Slice 280 best test accuracy: 53.06%
#
# Slice: 281
# Slice 281 best combined loss: 25.427138686180115
# Slice 281 best test f1: 0.6429
# Slice 281 best test accuracy: 59.18%
#
# Slice: 282
# Slice 282 best combined loss: 24.056508779525757
# Slice 282 best test f1: 0.5960
# Slice 282 best test accuracy: 58.50%
#
# Slice: 283
# Slice 283 best combined loss: 23.808282434940338
# Slice 283 best test f1: 0.6098
# Slice 283 best test accuracy: 56.46%
#
# Slice: 284
# Slice 284 best combined loss: 24.939112842082977
# Slice 284 best test f1: 0.5732
# Slice 284 best test accuracy: 52.38%
#
# Slice: 285
# Slice 285 best combined loss: 25.42992627620697
# Slice 285 best test f1: 0.5854
# Slice 285 best test accuracy: 53.74%
#
# Slice: 286
# Slice 286 best combined loss: 25.58210116624832
# Slice 286 best test f1: 0.6544
# Slice 286 best test accuracy: 48.98%
#
# Slice: 287
# Slice 287 best combined loss: 23.141865223646164
# Slice 287 best test f1: 0.6988
# Slice 287 best test accuracy: 65.99%
#
# Slice: 288
# Slice 288 best combined loss: 25.6066335439682
# Slice 288 best test f1: 0.6875
# Slice 288 best test accuracy: 52.38%
#
# Slice: 289
# Slice 289 best combined loss: 25.162114202976227
# Slice 289 best test f1: 0.6744
# Slice 289 best test accuracy: 61.90%
#
# Slice: 290
# Slice 290 best combined loss: 24.993418753147125
# Slice 290 best test f1: 0.6000
# Slice 290 best test accuracy: 56.46%
#
# Slice: 291
# Slice 291 best combined loss: 25.40616947412491
# Slice 291 best test f1: 0.6286
# Slice 291 best test accuracy: 55.78%
#
# Slice: 292
# Slice 292 best combined loss: 20.36713597178459
# Slice 292 best test f1: 0.7143
# Slice 292 best test accuracy: 67.35%
#
# Slice: 293
# Slice 293 best combined loss: 24.7966148853302
# Slice 293 best test f1: 0.6145
# Slice 293 best test accuracy: 56.46%
#
# Slice: 294
# Slice 294 best combined loss: 25.26080024242401
# Slice 294 best test f1: 0.6514
# Slice 294 best test accuracy: 58.50%
#
# Slice: 295
# Slice 295 best combined loss: 25.593661546707153
# Slice 295 best test f1: 0.6909
# Slice 295 best test accuracy: 53.74%
#
# Slice: 296
# Slice 296 best combined loss: 24.191119521856308
# Slice 296 best test f1: 0.6957
# Slice 296 best test accuracy: 66.67%
#
# Slice: 297
# Slice 297 best combined loss: 25.485814034938812
# Slice 297 best test f1: 0.6484
# Slice 297 best test accuracy: 56.46%
#
# Slice: 298
# Slice 298 best combined loss: 23.54251864552498
# Slice 298 best test f1: 0.6832
# Slice 298 best test accuracy: 65.31%
#
# Slice: 299
# Slice 299 best combined loss: 25.571999847888947
# Slice 299 best test f1: 0.6667
# Slice 299 best test accuracy: 53.74%
#
# Slice: 300
# Slice 300 best combined loss: 25.529342532157898
# Slice 300 best test f1: 0.6333
# Slice 300 best test accuracy: 55.10%
#
# Slice: 301
# Slice 301 best combined loss: 25.24281144142151
# Slice 301 best test f1: 0.6480
# Slice 301 best test accuracy: 57.14%
#
# Slice: 302
# Slice 302 best combined loss: 25.43254381418228
# Slice 302 best test f1: 0.6441
# Slice 302 best test accuracy: 57.14%
#
# Slice: 303
# Slice 303 best combined loss: 25.503615260124207
# Slice 303 best test f1: 0.5896
# Slice 303 best test accuracy: 51.70%
#
# Slice: 304
# Slice 304 best combined loss: 25.048784017562866
# Slice 304 best test f1: 0.5967
# Slice 304 best test accuracy: 50.34%
#
# Slice: 305
# Slice 305 best combined loss: 25.352721333503723
# Slice 305 best test f1: 0.6559
# Slice 305 best test accuracy: 56.46%
#
# Slice: 306
# Slice 306 best combined loss: 24.8822078704834
# Slice 306 best test f1: 0.6463
# Slice 306 best test accuracy: 60.54%
#
# Slice: 307
# Slice 307 best combined loss: 25.413476586341858
# Slice 307 best test f1: 0.6667
# Slice 307 best test accuracy: 60.54%
#
# Slice: 308
# Slice 308 best combined loss: 25.28619146347046
# Slice 308 best test f1: 0.7163
# Slice 308 best test accuracy: 58.50%
#
# Slice: 309
# Slice 309 best combined loss: 25.602552711963654
# Slice 309 best test f1: 0.6875
# Slice 309 best test accuracy: 52.38%
#
# Slice: 310
# Slice 310 best combined loss: 25.602864801883698
# Slice 310 best test f1: 0.6875
# Slice 310 best test accuracy: 52.38%
#
# Slice: 311
# Slice 311 best combined loss: 25.011790931224823
# Slice 311 best test f1: 0.5677
# Slice 311 best test accuracy: 54.42%
#
# Slice: 312
# Slice 312 best combined loss: 25.584687769412994
# Slice 312 best test f1: 0.6509
# Slice 312 best test accuracy: 49.66%
#
# Slice: 313
# Slice 313 best combined loss: 25.306165397167206
# Slice 313 best test f1: 0.6517
# Slice 313 best test accuracy: 57.82%
#
# Slice: 314
# Slice 314 best combined loss: 24.632174849510193
# Slice 314 best test f1: 0.5535
# Slice 314 best test accuracy: 51.70%
#
# Slice: 315
# Slice 315 best combined loss: 25.605133831501007
# Slice 315 best test f1: 0.6875
# Slice 315 best test accuracy: 52.38%
#
# Slice: 316
# Slice 316 best combined loss: 25.431577801704407
# Slice 316 best test f1: 0.6257
# Slice 316 best test accuracy: 54.42%
#
# Slice: 317
# Slice 317 best combined loss: 24.700418084859848
# Slice 317 best test f1: 0.6628
# Slice 317 best test accuracy: 60.54%
#
# Slice: 318
# Slice 318 best combined loss: 21.727129727602005
# Slice 318 best test f1: 0.7186
# Slice 318 best test accuracy: 68.03%
#
# Slice: 319
# Slice 319 best combined loss: 24.28229933977127
# Slice 319 best test f1: 0.6871
# Slice 319 best test accuracy: 65.31%
#
# Slice: 320
# Slice 320 best combined loss: 23.60760521888733
# Slice 320 best test f1: 0.6667
# Slice 320 best test accuracy: 61.90%
#
# Slice: 321
# Slice 321 best combined loss: 22.318088740110397
# Slice 321 best test f1: 0.7750
# Slice 321 best test accuracy: 75.51%
#
# Slice: 322
# Slice 322 best combined loss: 22.597898066043854
# Slice 322 best test f1: 0.6748
# Slice 322 best test accuracy: 63.95%
#
# Slice: 323
# Slice 323 best combined loss: 25.576230823993683
# Slice 323 best test f1: 0.6961
# Slice 323 best test accuracy: 57.82%
#
# Slice: 324
# Slice 324 best combined loss: 25.562863171100616
# Slice 324 best test f1: 0.6943
# Slice 324 best test accuracy: 59.86%
#
# Slice: 325
# Slice 325 best combined loss: 25.599664092063904
# Slice 325 best test f1: 0.6875
# Slice 325 best test accuracy: 52.38%
#
# Slice: 326
# Slice 326 best combined loss: 25.238882303237915
# Slice 326 best test f1: 0.6279
# Slice 326 best test accuracy: 56.46%
#
# Slice: 327
# Slice 327 best combined loss: 25.55703765153885
# Slice 327 best test f1: 0.6364
# Slice 327 best test accuracy: 51.02%
#
# Slice: 328
# Slice 328 best combined loss: 24.275719553232193
# Slice 328 best test f1: 0.6182
# Slice 328 best test accuracy: 57.14%
#
# Slice: 329
# Slice 329 best combined loss: 25.44130539894104
# Slice 329 best test f1: 0.6374
# Slice 329 best test accuracy: 55.10%
#
# Slice: 330
# Slice 330 best combined loss: 21.12341746687889
# Slice 330 best test f1: 0.7561
# Slice 330 best test accuracy: 72.79%
#
# Slice: 331
# Slice 331 best combined loss: 25.203799784183502
# Slice 331 best test f1: 0.5767
# Slice 331 best test accuracy: 53.06%
#
# Slice: 332
# Slice 332 best combined loss: 25.55725198984146
# Slice 332 best test f1: 0.6439
# Slice 332 best test accuracy: 50.34%
#
# Slice: 333
# Slice 333 best combined loss: 22.79403018951416
# Slice 333 best test f1: 0.6800
# Slice 333 best test accuracy: 67.35%
#
# Slice: 334
# Slice 334 best combined loss: 25.371952414512634
# Slice 334 best test f1: 0.5977
# Slice 334 best test accuracy: 52.38%
#
# Slice: 335
# Slice 335 best combined loss: 25.552084803581238
# Slice 335 best test f1: 0.6596
# Slice 335 best test accuracy: 56.46%
#
# Slice: 336
# Slice 336 best combined loss: 25.245380759239197
# Slice 336 best test f1: 0.6550
# Slice 336 best test accuracy: 59.86%
#
# Slice: 337
# Slice 337 best combined loss: 25.00989407300949
# Slice 337 best test f1: 0.6506
# Slice 337 best test accuracy: 60.54%
#
# Slice: 338
# Slice 338 best combined loss: 24.453390657901764
# Slice 338 best test f1: 0.6225
# Slice 338 best test accuracy: 61.22%
#
# Slice: 339
# Slice 339 best combined loss: 25.01283609867096
# Slice 339 best test f1: 0.6292
# Slice 339 best test accuracy: 55.10%
#
# Slice: 340
# Slice 340 best combined loss: 24.932327032089233
# Slice 340 best test f1: 0.6591
# Slice 340 best test accuracy: 59.18%
#
# Slice: 341
# Slice 341 best combined loss: 25.413561165332794
# Slice 341 best test f1: 0.6316
# Slice 341 best test accuracy: 57.14%
#
# Slice: 342
# Slice 342 best combined loss: 25.41745775938034
# Slice 342 best test f1: 0.6203
# Slice 342 best test accuracy: 51.70%
#
# Slice: 343
# Slice 343 best combined loss: 21.838763684034348
# Slice 343 best test f1: 0.7284
# Slice 343 best test accuracy: 70.07%
#
# Slice: 344
# Slice 344 best combined loss: 23.070299714803696
# Slice 344 best test f1: 0.6490
# Slice 344 best test accuracy: 63.95%
#
# Slice: 345
# Slice 345 best combined loss: 23.540577828884125
# Slice 345 best test f1: 0.5658
# Slice 345 best test accuracy: 55.10%
#
# Slice: 346
# Slice 346 best combined loss: 25.39459991455078
# Slice 346 best test f1: 0.6587
# Slice 346 best test accuracy: 61.22%
#
# Slice: 347
# Slice 347 best combined loss: 25.529341399669647
# Slice 347 best test f1: 0.6392
# Slice 347 best test accuracy: 52.38%
#
# Slice: 348
# Slice 348 best combined loss: 25.606473743915558
# Slice 348 best test f1: 0.6875
# Slice 348 best test accuracy: 52.38%
#
# Slice: 349
# Slice 349 best combined loss: 25.155713260173798
# Slice 349 best test f1: 0.6199
# Slice 349 best test accuracy: 55.78%
#
# Slice: 350
# Slice 350 best combined loss: 25.443822264671326
# Slice 350 best test f1: 0.7196
# Slice 350 best test accuracy: 63.95%
#
# Slice: 351
# Slice 351 best combined loss: 25.460466742515564
# Slice 351 best test f1: 0.6154
# Slice 351 best test accuracy: 52.38%
#
# Slice: 352
# Slice 352 best combined loss: 25.60491818189621
# Slice 352 best test f1: 0.6875
# Slice 352 best test accuracy: 52.38%
#
# Slice: 353
# Slice 353 best combined loss: 24.98521852493286
# Slice 353 best test f1: 0.5290
# Slice 353 best test accuracy: 50.34%
#
# Slice: 354
# Slice 354 best combined loss: 25.420619904994965
# Slice 354 best test f1: 0.6404
# Slice 354 best test accuracy: 56.46%
#
# Slice: 355
# Slice 355 best combined loss: 24.65155878663063
# Slice 355 best test f1: 0.6275
# Slice 355 best test accuracy: 61.22%
#
# Slice: 356
# Slice 356 best combined loss: 25.216451108455658
# Slice 356 best test f1: 0.6098
# Slice 356 best test accuracy: 56.46%
#
# Slice: 357
# Slice 357 best combined loss: 24.22135502099991
# Slice 357 best test f1: 0.6108
# Slice 357 best test accuracy: 55.78%
#
# Slice: 358
# Slice 358 best combined loss: 25.536012887954712
# Slice 358 best test f1: 0.6866
# Slice 358 best test accuracy: 57.14%
#
# Slice: 359
# Slice 359 best combined loss: 25.375544130802155
# Slice 359 best test f1: 0.6364
# Slice 359 best test accuracy: 56.46%
#
# Slice: 360
# Slice 360 best combined loss: 24.889727354049683
# Slice 360 best test f1: 0.6053
# Slice 360 best test accuracy: 59.18%
#
# Slice: 361
# Slice 361 best combined loss: 25.59378081560135
# Slice 361 best test f1: 0.6605
# Slice 361 best test accuracy: 50.34%
#
# Slice: 362
# Slice 362 best combined loss: 25.451268315315247
# Slice 362 best test f1: 0.6522
# Slice 362 best test accuracy: 56.46%
#
# Slice: 363
# Slice 363 best combined loss: 25.551088869571686
# Slice 363 best test f1: 0.6734
# Slice 363 best test accuracy: 55.78%
#
# Slice: 364
# Slice 364 best combined loss: 24.99958962202072
# Slice 364 best test f1: 0.7176
# Slice 364 best test accuracy: 67.35%
#
# Slice: 365
# Slice 365 best combined loss: 25.167539179325104
# Slice 365 best test f1: 0.6235
# Slice 365 best test accuracy: 56.46%
#
# Slice: 366
# Slice 366 best combined loss: 22.365629732608795
# Slice 366 best test f1: 0.6795
# Slice 366 best test accuracy: 65.99%
#
# Slice: 367
# Slice 367 best combined loss: 24.57013490796089
# Slice 367 best test f1: 0.5823
# Slice 367 best test accuracy: 55.10%
#
# Slice: 368
# Slice 368 best combined loss: 23.58890575170517
# Slice 368 best test f1: 0.6585
# Slice 368 best test accuracy: 61.90%
#
# Slice: 369
# Slice 369 best combined loss: 25.499074697494507
# Slice 369 best test f1: 0.6893
# Slice 369 best test accuracy: 62.59%
#
# Slice: 370
# Slice 370 best combined loss: 24.57251262664795
# Slice 370 best test f1: 0.6626
# Slice 370 best test accuracy: 62.59%
#
# Slice: 371
# Slice 371 best combined loss: 25.15040874481201
# Slice 371 best test f1: 0.6463
# Slice 371 best test accuracy: 60.54%
#
# Slice: 372
# Slice 372 best combined loss: 25.075811088085175
# Slice 372 best test f1: 0.5750
# Slice 372 best test accuracy: 53.74%
#
# Slice: 373
# Slice 373 best combined loss: 25.430802643299103
# Slice 373 best test f1: 0.6554
# ...
# Slice 644 best test accuracy: 59.86%
#
# Slice: 645
# Slice 645 best combined loss: 25.5218066573143
# Slice 645 best test f1: 0.6839
# Slice 645 best test accuracy: 58.50%
#
# Slice: 646
# Slice 646 best combined loss: 25.49449598789215
# Slice 646 best test f1: 0.6629
# Slice 646 best test accuracy: 59.18%
#
# Slice: 647
# Slice 647 best combined loss: 24.71576637029648
# Slice 647 best test f1: 0.6813
# Slice 647 best test accuracy: 60.54%
#
# Slice: 648
# Slice 648 best combined loss: 25.595811545848846
# Slice 648 best test f1: 0.6875
# Slice 648 best test accuracy: 52.38%
#
# Slice: 649
# Slice 649 best combined loss: 25.45809441804886
# Slice 649 best test f1: 0.5581
# Slice 649 best test accuracy: 48.30%
#
# Slice: 650
# Slice 650 best combined loss: 24.735854148864746
# Slice 650 best test f1: 0.6667
# Slice 650 best test accuracy: 61.22%
#
# Slice: 651
# Slice 651 best combined loss: 25.152812004089355
# Slice 651 best test f1: 0.6316
# Slice 651 best test accuracy: 57.14%
#
# Slice: 652
# Slice 652 best combined loss: 22.57803100347519
# Slice 652 best test f1: 0.6951
# Slice 652 best test accuracy: 65.99%
#
# Slice: 653
# Slice 653 best combined loss: 24.97405844926834
# Slice 653 best test f1: 0.6316
# Slice 653 best test accuracy: 57.14%
#
# Slice: 654
# Slice 654 best combined loss: 25.32496154308319
# Slice 654 best test f1: 0.5965
# Slice 654 best test accuracy: 53.06%
#
# Slice: 655
# Slice 655 best combined loss: 24.063377618789673
# Slice 655 best test f1: 0.6065
# Slice 655 best test accuracy: 58.50%
#
# Slice: 656
# Slice 656 best combined loss: 25.59585040807724
# Slice 656 best test f1: 0.7037
# Slice 656 best test accuracy: 56.46%
#
# Slice: 657
# Slice 657 best combined loss: 23.76527264714241
# Slice 657 best test f1: 0.6543
# Slice 657 best test accuracy: 61.90%
#
# Slice: 658
# Slice 658 best combined loss: 24.66595149040222
# Slice 658 best test f1: 0.6797
# Slice 658 best test accuracy: 66.67%
#
# Slice: 659
# Slice 659 best combined loss: 25.600042164325714
# Slice 659 best test f1: 0.6875
# Slice 659 best test accuracy: 52.38%
#
# Slice: 660
# Slice 660 best combined loss: 24.447264790534973
# Slice 660 best test f1: 0.6541
# Slice 660 best test accuracy: 62.59%
#
# Slice: 661
# Slice 661 best combined loss: 25.5650794506073
# Slice 661 best test f1: 0.6595
# Slice 661 best test accuracy: 57.14%
#
# Slice: 662
# Slice 662 best combined loss: 24.684055268764496
# Slice 662 best test f1: 0.6433
# Slice 662 best test accuracy: 58.50%
#
# Slice: 663
# Slice 663 best combined loss: 25.17729663848877
# Slice 663 best test f1: 0.6391
# Slice 663 best test accuracy: 58.50%
#
# Slice: 664
# Slice 664 best combined loss: 24.217183768749237
# Slice 664 best test f1: 0.6265
# Slice 664 best test accuracy: 57.82%
#
# Slice: 665
# Slice 665 best combined loss: 23.86398136615753
# Slice 665 best test f1: 0.6545
# Slice 665 best test accuracy: 61.22%
#
# Slice: 666
# Slice 666 best combined loss: 25.597027719020844
# Slice 666 best test f1: 0.6937
# Slice 666 best test accuracy: 53.74%
#
# Slice: 667
# Slice 667 best combined loss: 25.24931502342224
# Slice 667 best test f1: 0.5153
# Slice 667 best test accuracy: 46.26%
#
# Slice: 668
# Slice 668 best combined loss: 25.56271106004715
# Slice 668 best test f1: 0.6605
# Slice 668 best test accuracy: 50.34%
#
# Slice: 669
# Slice 669 best combined loss: 20.81673789024353
# Slice 669 best test f1: 0.6750
# Slice 669 best test accuracy: 64.63%
#
# Slice: 670
# Slice 670 best combined loss: 25.165597438812256
# Slice 670 best test f1: 0.6444
# Slice 670 best test accuracy: 56.46%
#
# Slice: 671
# Slice 671 best combined loss: 25.36789846420288
# Slice 671 best test f1: 0.7219
# Slice 671 best test accuracy: 68.03%
#
# Slice: 672
# Slice 672 best combined loss: 24.683566093444824
# Slice 672 best test f1: 0.6282
# Slice 672 best test accuracy: 60.54%
#
# Slice: 673
# Slice 673 best combined loss: 24.712956726551056
# Slice 673 best test f1: 0.6341
# Slice 673 best test accuracy: 59.18%
#
# Slice: 674
# Slice 674 best combined loss: 24.122754514217377
# Slice 674 best test f1: 0.6386
# Slice 674 best test accuracy: 59.18%
#
# Slice: 675
# Slice 675 best combined loss: 25.584305584430695
# Slice 675 best test f1: 0.6667
# Slice 675 best test accuracy: 55.10%
#
# Slice: 676
# Slice 676 best combined loss: 25.54474586248398
# Slice 676 best test f1: 0.6344
# Slice 676 best test accuracy: 53.74%
#
# Slice: 677
# Slice 677 best combined loss: 24.368952333927155
# Slice 677 best test f1: 0.6905
# Slice 677 best test accuracy: 64.63%
#
# Slice: 678
# Slice 678 best combined loss: 24.5849087536335
# Slice 678 best test f1: 0.6127
# Slice 678 best test accuracy: 54.42%
#
# Slice: 679
# Slice 679 best combined loss: 23.300564467906952
# Slice 679 best test f1: 0.7439
# Slice 679 best test accuracy: 71.43%
#
# Slice: 680
# Slice 680 best combined loss: 25.259110987186432
# Slice 680 best test f1: 0.5882
# Slice 680 best test accuracy: 52.38%
#
# Slice: 681
# Slice 681 best combined loss: 25.510780453681946
# Slice 681 best test f1: 0.6524
# Slice 681 best test accuracy: 55.78%
#
# Slice: 682
# Slice 682 best combined loss: 25.131279170513153
# Slice 682 best test f1: 0.6509
# Slice 682 best test accuracy: 59.86%
#
# Slice: 683
# Slice 683 best combined loss: 25.580082952976227
# Slice 683 best test f1: 0.6730
# Slice 683 best test accuracy: 53.06%
#
# Slice: 684
# Slice 684 best combined loss: 25.58495992422104
# Slice 684 best test f1: 0.6941
# Slice 684 best test accuracy: 54.42%
#
# Slice: 685
# Slice 685 best combined loss: 25.379689693450928
# Slice 685 best test f1: 0.5663
# Slice 685 best test accuracy: 51.02%
#
# Slice: 686
# Slice 686 best combined loss: 22.518725037574768
# Slice 686 best test f1: 0.7665
# Slice 686 best test accuracy: 73.47%
#
# Slice: 687
# Slice 687 best combined loss: 25.60676747560501
# Slice 687 best test f1: 0.6875
# Slice 687 best test accuracy: 52.38%
#
# Slice: 688
# Slice 688 best combined loss: 25.428686797618866
# Slice 688 best test f1: 0.5600
# Slice 688 best test accuracy: 47.62%
#
# Slice: 689
# Slice 689 best combined loss: 25.275471210479736
# Slice 689 best test f1: 0.6087
# Slice 689 best test accuracy: 57.14%
#
# Slice: 690
# Slice 690 best combined loss: 24.351268887519836
# Slice 690 best test f1: 0.6839
# Slice 690 best test accuracy: 66.67%
#
# Slice: 691
# Slice 691 best combined loss: 25.569565176963806
# Slice 691 best test f1: 0.6635
# Slice 691 best test accuracy: 52.38%
#
# Slice: 692
# Slice 692 best combined loss: 20.766074925661087
# Slice 692 best test f1: 0.6752
# Slice 692 best test accuracy: 65.31%
#
# Slice: 693
# Slice 693 best combined loss: 24.18123486638069
# Slice 693 best test f1: 0.6871
# Slice 693 best test accuracy: 65.31%
#
# Slice: 694
# Slice 694 best combined loss: 25.60146689414978
# Slice 694 best test f1: 0.6968
# Slice 694 best test accuracy: 54.42%
#
# Slice: 695
# Slice 695 best combined loss: 25.528758585453033
# Slice 695 best test f1: 0.6601
# Slice 695 best test accuracy: 53.06%
#
# Slice: 696
# Slice 696 best combined loss: 25.00076997280121
# Slice 696 best test f1: 0.5767
# Slice 696 best test accuracy: 53.06%
#
# Slice: 697
# Slice 697 best combined loss: 24.642278373241425
# Slice 697 best test f1: 0.7250
# Slice 697 best test accuracy: 70.07%
#
# Slice: 698
# Slice 698 best combined loss: 24.870381593704224
# Slice 698 best test f1: 0.5478
# Slice 698 best test accuracy: 51.70%
#
# Slice: 699
# Slice 699 best combined loss: 22.415805369615555
# Slice 699 best test f1: 0.6543
# Slice 699 best test accuracy: 61.90%
#
# Slice: 700
# Slice 700 best combined loss: 24.114367604255676
# Slice 700 best test f1: 0.6173
# Slice 700 best test accuracy: 57.82%
#
# Slice: 701
# Slice 701 best combined loss: 24.81097424030304
# Slice 701 best test f1: 0.6625
# Slice 701 best test accuracy: 63.27%
#
# Slice: 702
# Slice 702 best combined loss: 25.134644865989685
# Slice 702 best test f1: 0.6545
# Slice 702 best test accuracy: 61.22%
#
# Slice: 703
# Slice 703 best combined loss: 25.08597195148468
# Slice 703 best test f1: 0.5767
# Slice 703 best test accuracy: 53.06%
#
# Slice: 704
# Slice 704 best combined loss: 25.595479667186737
# Slice 704 best test f1: 0.6875
# Slice 704 best test accuracy: 52.38%
#
# Slice: 705
# Slice 705 best combined loss: 24.137942135334015
# Slice 705 best test f1: 0.5963
# Slice 705 best test accuracy: 55.78%
#
# Slice: 706
# Slice 706 best combined loss: 24.91810792684555
# Slice 706 best test f1: 0.5988
# Slice 706 best test accuracy: 54.42%
#
# Slice: 707
# Slice 707 best combined loss: 25.445765674114227
# Slice 707 best test f1: 0.6120
# Slice 707 best test accuracy: 51.70%
#
# Slice: 708
# Slice 708 best combined loss: 22.963813930749893
# Slice 708 best test f1: 0.7407
# Slice 708 best test accuracy: 71.43%
#
# Slice: 709
# Slice 709 best combined loss: 25.449530959129333
# Slice 709 best test f1: 0.6034
# Slice 709 best test accuracy: 51.70%
#
# Slice: 710
# Slice 710 best combined loss: 25.580197930336
# Slice 710 best test f1: 0.7053
# Slice 710 best test accuracy: 58.50%
#
# Slice: 711
# Slice 711 best combined loss: 25.556516468524933
# Slice 711 best test f1: 0.6250
# Slice 711 best test accuracy: 51.02%
#
# Slice: 712
# Slice 712 best combined loss: 24.800316989421844
# Slice 712 best test f1: 0.6375
# Slice 712 best test accuracy: 60.54%
#
# Slice: 713
# Slice 713 best combined loss: 24.62323659658432
# Slice 713 best test f1: 0.6824
# Slice 713 best test accuracy: 63.27%
#
# Slice: 714
# Slice 714 best combined loss: 25.56302511692047
# Slice 714 best test f1: 0.6061
# Slice 714 best test accuracy: 46.94%
#
# Slice: 715
# Slice 715 best combined loss: 25.60143554210663
# Slice 715 best test f1: 0.6875
# Slice 715 best test accuracy: 52.38%
#
# Slice: 716
# Slice 716 best combined loss: 25.5657257437706
# Slice 716 best test f1: 0.6860
# Slice 716 best test accuracy: 55.78%
#
# Slice: 717
# Slice 717 best combined loss: 25.5549755692482
# Slice 717 best test f1: 0.6359
# Slice 717 best test accuracy: 51.70%
#
# Slice: 718
# Slice 718 best combined loss: 25.413308680057526
# Slice 718 best test f1: 0.5455
# Slice 718 best test accuracy: 45.58%
#
# Slice: 719
# Slice 719 best combined loss: 23.27866080403328
# Slice 719 best test f1: 0.6490
# Slice 719 best test accuracy: 63.95%
#
# Slice: 720
# Slice 720 best combined loss: 24.13905668258667
# Slice 720 best test f1: 0.7263
# Slice 720 best test accuracy: 66.67%
#
# Slice: 721
# Slice 721 best combined loss: 24.03231853246689
# Slice 721 best test f1: 0.7470
# Slice 721 best test accuracy: 71.43%
#
# Slice: 722
# Slice 722 best combined loss: 23.804431915283203
# Slice 722 best test f1: 0.5696
# Slice 722 best test accuracy: 53.74%
#
# Slice: 723
# Slice 723 best combined loss: 25.137819051742554
# Slice 723 best test f1: 0.6012
# Slice 723 best test accuracy: 55.78%
#
# Slice: 724
# Slice 724 best combined loss: 24.97973757982254
# Slice 724 best test f1: 0.6624
# Slice 724 best test accuracy: 63.95%
#
# Slice: 725
# Slice 725 best combined loss: 24.83497393131256
# Slice 725 best test f1: 0.6590
# Slice 725 best test accuracy: 59.86%
#
# Slice: 726
# Slice 726 best combined loss: 23.97487038373947
# Slice 726 best test f1: 0.6250
# Slice 726 best test accuracy: 59.18%
#
# Slice: 727
# Slice 727 best combined loss: 25.522534489631653
# Slice 727 best test f1: 0.6444
# Slice 727 best test accuracy: 56.46%
#
# Slice: 728
# Slice 728 best combined loss: 25.489478647708893
# Slice 728 best test f1: 0.6455
# Slice 728 best test accuracy: 54.42%
#
# Slice: 729
# Slice 729 best combined loss: 25.172337770462036
# Slice 729 best test f1: 0.6024
# Slice 729 best test accuracy: 55.10%
#
# Slice: 730
# Slice 730 best combined loss: 24.99352139234543
# Slice 730 best test f1: 0.5912
# Slice 730 best test accuracy: 55.78%
#
# Slice: 731
# Slice 731 best combined loss: 24.52464586496353
# Slice 731 best test f1: 0.5926
# Slice 731 best test accuracy: 55.10%
#
# Slice: 732
# Slice 732 best combined loss: 25.38208931684494
# Slice 732 best test f1: 0.6854
# Slice 732 best test accuracy: 61.90%
#
# Slice: 733
# Slice 733 best combined loss: 24.994355261325836
# Slice 733 best test f1: 0.5395
# Slice 733 best test accuracy: 52.38%
#
# Slice: 734
# Slice 734 best combined loss: 25.351407647132874
# Slice 734 best test f1: 0.6098
# Slice 734 best test accuracy: 56.46%
#
# Slice: 735
# Slice 735 best combined loss: 24.087755769491196
# Slice 735 best test f1: 0.6667
# Slice 735 best test accuracy: 61.22%
#
# Slice: 736
# Slice 736 best combined loss: 23.658394753932953
# Slice 736 best test f1: 0.6424
# Slice 736 best test accuracy: 59.86%
#
# Slice: 737
# Slice 737 best combined loss: 25.58457762002945
# Slice 737 best test f1: 0.6977
# Slice 737 best test accuracy: 55.78%
#
# Slice: 738
# Slice 738 best combined loss: 24.950447142124176
# Slice 738 best test f1: 0.6629
# Slice 738 best test accuracy: 59.86%
#
# Slice: 739
# Slice 739 best combined loss: 23.57894667983055
# Slice 739 best test f1: 0.5513
# Slice 739 best test accuracy: 52.38%
#
# Slice: 740
# Slice 740 best combined loss: 25.5871804356575
# Slice 740 best test f1: 0.6700
# Slice 740 best test accuracy: 54.42%
#
# Slice: 741
# Slice 741 best combined loss: 23.8802410364151
# Slice 741 best test f1: 0.7000
# Slice 741 best test accuracy: 67.35%
#
# Slice: 742
# Slice 742 best combined loss: 25.604843080043793
# Slice 742 best test f1: 0.6906
# Slice 742 best test accuracy: 53.06%
#
# Slice: 743
# Slice 743 best combined loss: 24.56407791376114
# Slice 743 best test f1: 0.6220
# Slice 743 best test accuracy: 57.82%
#
# Slice: 744
# Slice 744 best combined loss: 25.599220037460327
# Slice 744 best test f1: 0.6875
# Slice 744 best test accuracy: 52.38%
#
# Slice: 745
# Slice 745 best combined loss: 18.702709510922432
# Slice 745 best test f1: 0.8025
# Slice 745 best test accuracy: 78.91%
#
# Slice: 746
# Slice 746 best combined loss: 25.577878654003143
# Slice 746 best test f1: 0.6762
# Slice 746 best test accuracy: 53.74%
#
# Slice: 747
# Slice 747 best combined loss: 25.399010241031647
# Slice 747 best test f1: 0.6557
# Slice 747 best test accuracy: 57.14%
#
# Slice: 748
# Slice 748 best combined loss: 25.33281284570694
# Slice 748 best test f1: 0.6705
# Slice 748 best test accuracy: 61.22%
#
# Slice: 749
# Slice 749 best combined loss: 25.596565902233124
# Slice 749 best test f1: 0.6816
# Slice 749 best test accuracy: 51.70%
#
# Slice: 750
# Slice 750 best combined loss: 24.683229625225067
# Slice 750 best test f1: 0.6994
# Slice 750 best test accuracy: 66.67%
#
# Slice: 751
# Slice 751 best combined loss: 24.22136151790619
# Slice 751 best test f1: 0.6380
# Slice 751 best test accuracy: 59.86%
#
# Slice: 752
# Slice 752 best combined loss: 24.55428236722946
# Slice 752 best test f1: 0.6125
# Slice 752 best test accuracy: 57.82%
#
# Slice: 753
# Slice 753 best combined loss: 25.533747375011444
# Slice 753 best test f1: 0.5946
# Slice 753 best test accuracy: 48.98%
#
# Slice: 754
# Slice 754 best combined loss: 24.113865613937378
# Slice 754 best test f1: 0.5987
# Slice 754 best test accuracy: 57.14%
#
# Slice: 755
# Slice 755 best combined loss: 23.21344217658043
# Slice 755 best test f1: 0.7229
# Slice 755 best test accuracy: 68.71%
#
# Slice: 756
# Slice 756 best combined loss: 24.807954490184784
# Slice 756 best test f1: 0.6145
# Slice 756 best test accuracy: 56.46%
#
# Slice: 757
# Slice 757 best combined loss: 25.586573600769043
# Slice 757 best test f1: 0.6698
# Slice 757 best test accuracy: 52.38%
#
# Slice: 758
# Slice 758 best combined loss: 25.580320119857788
# Slice 758 best test f1: 0.7475
# Slice 758 best test accuracy: 65.99%
#
# Slice: 759
# Slice 759 best combined loss: 25.58510994911194
# Slice 759 best test f1: 0.6909
# Slice 759 best test accuracy: 53.74%
#
# Slice: 760
# Slice 760 best combined loss: 25.376794695854187
# Slice 760 best test f1: 0.5476
# Slice 760 best test accuracy: 48.30%
#
# Slice: 761
# Slice 761 best combined loss: 25.551194846630096
# Slice 761 best test f1: 0.6383
# Slice 761 best test accuracy: 53.74%
#
# Slice: 762
# Slice 762 best combined loss: 20.768802404403687
# Slice 762 best test f1: 0.7453
# Slice 762 best test accuracy: 72.11%
#
# Slice: 763
# Slice 763 best combined loss: 25.004413664340973
# Slice 763 best test f1: 0.6548
# Slice 763 best test accuracy: 60.54%
#
# Slice: 764
# Slice 764 best combined loss: 25.497040688991547
# Slice 764 best test f1: 0.6562
# Slice 764 best test accuracy: 55.10%
#
# Slice: 765
# Slice 765 best combined loss: 25.192937195301056
# Slice 765 best test f1: 0.6243
# Slice 765 best test accuracy: 55.78%
#
# Slice: 766
# Slice 766 best combined loss: 25.40045976638794
# Slice 766 best test f1: 0.5731
# Slice 766 best test accuracy: 50.34%
#
# Slice: 767
# Slice 767 best combined loss: 25.51080983877182
# Slice 767 best test f1: 0.6096
# Slice 767 best test accuracy: 50.34%
#
# 768

# %%
# plot histograms of the test accuracies and f1 scores
plt.hist(all_test_accs, bins=20)
plt.title('Test accuracies')
plt.show()

plt.hist(all_test_f1s, bins=20)
plt.title('Test f1 scores')
plt.show()

# %%
# plot bar chart of the accuracies
plt.bar(range(768), all_test_accs)
plt.title('Test accuracies')
plt.show()

# %%
print(all_test_accs[:10])
# Out:
# [0.6530612244897959, 0.6802721088435374, 0.6394557823129252, 0.5918367346938775, 0.7142857142857143, 0.5714285714285714, 0.5782312925170068, 0.6598639455782312, 0.5510204081632653, 0.5170068027210885]

# %%
# convert list of tensors into list of floats
all_test_accs_val = [acc.item() for acc in all_test_accs]
all_test_f1s_val = [f1.item() for f1 in all_test_f1s]

print(all_test_accs_val[:10])
print(all_test_f1s_val[:10])
# Out:
# [0.6530612244897959, 0.6802721088435374, 0.6394557823129252, 0.5918367346938775, 0.7142857142857143, 0.5714285714285714, 0.5782312925170068, 0.6598639455782312, 0.5510204081632653, 0.5170068027210885]
# [0.6666666666666666, 0.7044025157232705, 0.6900584795321637, 0.6385542168674699, 0.7236842105263158, 0.64, 0.6666666666666666, 0.6875000000000001, 0.6024096385542169, 0.6570048309178743]

# %%
all_test_accs_val = np.array(all_test_accs_val)
all_test_f1s_val = np.array(all_test_f1s_val)
all_combined_losses = np.array(all_combined_losses)

# %%
# find the indices of the top 10 slices
top_10_indices = np.argsort(all_test_accs_val)[-10:]
top_10_indices_f1 = np.argsort(all_test_f1s_val)[-10:]
print(top_10_indices)
print(top_10_indices_f1)
print(all_test_accs_val[top_10_indices])
print(all_test_f1s_val[top_10_indices])
print(all_combined_losses[top_10_indices])
# Out:
# [686  34  48 529 522 321 614  44 745 215]
# [ 27  48 686 529 321 522 614  44 215 745]
# [0.73469388 0.73469388 0.7414966  0.7414966  0.75510204 0.75510204
#  0.75510204 0.76190476 0.78911565 0.78911565]
# [0.76646707 0.75159236 0.7625     0.77380952 0.77777778 0.775
#  0.7804878  0.7826087  0.80254777 0.79194631]
# [22.51872504 23.89981192 22.44156882 21.17535567 19.92017455 22.31808874
#  21.29881737 17.50767986 18.70270951 20.97469044]

# %%
# create a dataframe with accuracy and loss
df_acc_loss = pd.DataFrame({
    'accuracy': all_test_accs_val,
    'f1': all_test_f1s,
    'loss': all_combined_losses
})

print(df_acc_loss[:10])

# save the dataframe to a csv file
df_acc_loss.to_csv(f"llm-outputs/{classification}_xl_bruteforce_acc_loss.csv", index=False)
# Out:
#    accuracy        f1       loss
# 0  0.653061  0.666667  24.867186
# 1  0.680272  0.704403  24.007130
# 2  0.639456  0.690058  24.384098
# 3  0.591837  0.638554  24.524148
# 4  0.714286  0.723684  23.788191
# 5  0.571429  0.640000  25.252940
# 6  0.578231  0.666667  25.430784
# 7  0.659864  0.687500  24.669885
# 8  0.551020  0.602410  24.671768
# 9  0.517007  0.657005  25.542035

# %% [markdown]
# ## Analysis

# %%
# for each of the top 10 slices,
# average the embeddings of the pro words and the non words

pro_emb_avg = []
non_emb_avg = []

for i in top_10_indices:
    df_slice = pd.DataFrame({
        # 'word': df_train['word'],
        'embedding': df_train[str(i)],
        'label': df_train['label']
    })

    df_slice_pro = df_slice[df_slice['label'] == 1]
    df_slice_non = df_slice[df_slice['label'] == 0]

    pro_emb_avg.append(np.mean(df_slice_pro['embedding']))
    non_emb_avg.append(np.mean(df_slice_non['embedding']))

# create a dataframe with the average embeddings
df_top10_avg = pd.DataFrame({
    'index': top_10_indices,
    'pro': pro_emb_avg,
    'non': non_emb_avg,
    'diff': abs(np.array(pro_emb_avg) - np.array(non_emb_avg)),
    'acc': all_test_accs_val[top_10_indices],
    'f1': all_test_f1s_val[top_10_indices],
    'loss': all_combined_losses[top_10_indices]
})

print(df_top10_avg)

# save the dataframe to a csv file
df_top10_avg.to_csv(f"llm-outputs/{classification}_xl_bruteforce_top10_metrics.csv", index=False)
# Out:
#    index       pro       non      diff       acc        f1       loss
# 0    686  0.023464 -0.159688  0.183153  0.734694  0.766467  22.518725
# 1     34 -0.342656 -0.540059  0.197403  0.734694  0.751592  23.899812
# 2     48 -0.005607 -0.282237  0.276631  0.741497  0.762500  22.441569
# 3    529 -0.195739 -0.385771  0.190033  0.741497  0.773810  21.175356
# 4    522 -0.154906 -0.492161  0.337255  0.755102  0.777778  19.920175
# 5    321  0.277829  0.467063  0.189234  0.755102  0.775000  22.318089
# 6    614  0.050826  0.203034  0.152208  0.755102  0.780488  21.298817
# 7     44  0.206909 -0.147362  0.354271  0.761905  0.782609  17.507680
# 8    745  0.126698 -0.205403  0.332101  0.789116  0.802548  18.702710
# 9    215 -0.107674 -0.287794  0.180120  0.789116  0.791946  20.974690

# %%
def plot_axis_hist(slice):
    df_slice = pd.DataFrame({
        # 'word': df_train['word'],
        'embedding': df_train[str(slice)],
        'label': df_train['label']
    })

    df_slice_pro = df_slice[df_slice['label'] == 1]
    df_slice_non = df_slice[df_slice['label'] == 0]

    # draw a histogram of the embeddings, with the pro words in red and the non-pro words in blue
    plt.hist(df_slice_pro['embedding'], bins=30, color='red', alpha=0.5)
    plt.hist(df_slice_non['embedding'], bins=30, color='blue', alpha=0.5)
    plt.title(f"Axis {slice} histogram")
    plt.show()

# %%
for i in top_10_indices:
    plot_axis_hist(i)

# %%
# create a dataframe with the top 10 slices
df_top10 = pd.DataFrame(df_train[str(i)] for i in top_10_indices)
df_top10 = df_top10.T
df_top10.columns = [str(i) for i in df_top10.columns]
df_top10['label'] = df_train['label']
df_top10['word'] = df_train['word']

print(df_top10[:10])

# save the dataframe to a csv file
df_top10.to_csv(f"llm-outputs/{classification}_xl_bruteforce_top10_embs.csv", index=False)
# Out:
#         686        34        48       529       522       321       614  \
# 0 -0.151752 -0.508748 -0.062794 -0.280756 -0.429892  0.208205  0.220784
# 1 -0.162016 -0.913032  0.352588 -0.536503 -0.202539  0.008597  0.032351
# 2  0.090103 -0.475712  0.243622 -0.136099 -0.080676  0.044642 -0.011919
# 3 -0.145662 -0.379210 -0.058488 -0.071198 -0.538185  0.118923  0.038276
# 4 -0.103138 -0.766173  0.412607 -0.212625  0.348283  0.506507  0.072227
# 5 -0.029768  0.118873  0.005900  0.065004  0.077368  0.413329 -0.069609
# 6  0.259126 -0.526566  0.236324 -0.503119 -0.436275  0.368016  0.413931
# 7 -0.257084 -0.342787 -0.174513 -0.320644 -0.429034 -0.075554  0.025968
# 8  0.223989 -0.075304 -0.114202 -0.338261 -0.354848  0.396354 -0.134553
# 9  0.403347 -0.565080 -0.737566  0.217373 -0.286796  0.208764  0.240053
#
#          44       745       215  label      word
# 0  0.102210 -0.142448 -0.036598      1    person
# 1  0.129483  0.020498 -0.061561      1      bear
# 2 -0.056978 -0.384304 -0.187643      1      purr
# 3  0.057629 -0.130183 -0.128870      1      sink
# 4  0.355707  0.448718 -0.154770      1      idea
# 5  0.052167  0.230850 -0.143764      1  opulence
# 6  0.652059  0.049534 -0.099843      1      line
# 7 -0.185471  0.085594 -0.002670      1    clique
# 8 -0.049981  0.490052  0.037946      1      skis
# 9  0.380823 -0.316697 -0.199180      1      rain

# %%
df_top10_train = pd.DataFrame(df_train[str(i)] for i in top_10_indices)
df_top10_train = df_top10_train.T

# combine all column values into list stored in one column
df_top10_train['embedding'] = df_top10_train.values.tolist()

# remove all columns except the list of embeddings
df_top10_train = df_top10_train[['embedding']]
df_top10_train['label'] = df_train['label']
df_top10_train['word'] = df_train['word']

print(df_top10_train[:10])
print(len(df_top10_train['embedding'][0]))
# Out:
#                                            embedding  label      word
# 0  [-0.1517522633075714, -0.5087480545043945, -0....      1    person
# 1  [-0.16201575100421906, -0.9130323529243469, 0....      1      bear
# 2  [0.09010278433561325, -0.4757117033004761, 0.2...      1      purr
# 3  [-0.1456623077392578, -0.37921014428138733, -0...      1      sink
# 4  [-0.10313776880502701, -0.7661731243133545, 0....      1      idea
# 5  [-0.02976801246404648, 0.11887335777282715, 0....      1  opulence
# 6  [0.25912636518478394, -0.5265657305717468, 0.2...      1      line
# 7  [-0.257084459066391, -0.3427872955799103, -0.1...      1    clique
# 8  [0.2239888310432434, -0.0753038078546524, -0.1...      1      skis
# 9  [0.4033471643924713, -0.5650796890258789, -0.7...      1      rain
# 10

# %%
df_top10_test = pd.DataFrame(df_test[str(i)] for i in top_10_indices)
df_top10_test = df_top10_test.T

# combine all column values into list stored in one column
df_top10_test['embedding'] = df_top10_test.values.tolist()

# remove all columns except the list of embeddings
df_top10_test = df_top10_test[['embedding']]
df_top10_test['label'] = df_test['label']
df_top10_test['word'] = df_test['word']

print(df_top10_test[:10])
print(len(df_top10_test['embedding'][0]))
# Out:
#                                            embedding  label        word
# 0  [0.18564677238464355, -0.7364640831947327, -0....      1       apple
# 1  [-0.09736441820859909, -0.7058984041213989, 0....      1      family
# 2  [-0.19978146255016327, -0.3408772051334381, -0...      1       sound
# 3  [-0.028825564309954643, -0.6584175825119019, 0...      1    keyboard
# 4  [-0.008437694050371647, -0.8196252584457397, -...      1       anger
# 5  [0.030518583953380585, -0.3142611086368561, -0...      1         bus
# 6  [0.06297377496957779, -0.09528683871030807, -0...      1  conformity
# 7  [0.13638968765735626, -0.907825767993927, 0.28...      1         joy
# 8  [0.26729944348335266, -0.37102776765823364, 0....      1        fish
# 9  [0.027840375900268555, -0.055824704468250275, ...      1     trading
# 10

# %%
top10_train_loader, top10_test_loader = create_dataloaders(df_top10_train, df_top10_test)

# take the best of 3 runs
top10_best_test_acc = 0
top10_best_test_f1 = 0

for i in range(10):
    net, top10_best_combined_loss = train_model(top10_train_loader, 10)

    # train_acc, train_f1 = evaluate_net(top10_train_loader, net)
    test_acc, test_f1 = evaluate_net(top10_test_loader, net)

    if test_acc > best_test_acc and test_f1 > best_test_f1:
        top10_best_test_acc = test_acc
        top10_best_test_f1 = test_f1

print(f'Top 10 axes best combined loss: {top10_best_combined_loss}')
print(f'Top 10 axes best test f1: {top10_best_test_f1:.4f}')
print(f'Top 10 axes best test accuracy: {top10_best_test_acc*100:.2f}% \n')
# Out:
# Top 10 axes best combined loss: 12.64771082624793
# Top 10 axes best test f1: 0.8662
# Top 10 axes best test accuracy: 85.71%

# %%
df_full_train = pd.DataFrame(df_train[str(i)] for i in range(768))
df_full_train = df_full_train.T

# combine all column values into list stored in one column
df_full_train['embedding'] = df_full_train.values.tolist()

# remove all columns except the list of embeddings
df_full_train = df_full_train[['embedding']]
df_full_train['label'] = df_train['label']
df_full_train['word'] = df_train['word']

print(df_full_train[:10])
print(len(df_full_train))
print(len(df_full_train['embedding'][0]))
# Out:
#                                            embedding  label      word
# 0  [-0.374845415353775, -0.25104567408561707, -0....      1    person
# 1  [0.2614474594593048, 0.36543747782707214, -0.2...      1      bear
# 2  [-0.33159852027893066, -0.3760782480239868, 0....      1      purr
# 3  [0.19302485883235931, 0.16142483055591583, -0....      1      sink
# 4  [0.2232976257801056, -0.0603032261133194, -0.2...      1      idea
# 5  [-0.17045091092586517, -0.24760545790195465, 0...      1  opulence
# 6  [0.20358100533485413, -0.8333743810653687, -0....      1      line
# 7  [0.08710736036300659, -0.5675134658813477, -0....      1    clique
# 8  [0.0936114490032196, 0.024590693414211273, 0.2...      1      skis
# 9  [0.7371596693992615, 0.6527073979377747, 0.096...      1      rain
# 584
# 768

# %%
df_full_test = pd.DataFrame(df_test[str(i)] for i in range(768))
df_full_test = df_full_test.T

# combine all column values into list stored in one column
df_full_test['embedding'] = df_full_test.values.tolist()

# remove all columns except the list of embeddings
df_full_test = df_full_test[['embedding']]
df_full_test['label'] = df_test['label']
df_full_test['word'] = df_test['word']

print(df_full_test[:10])
print(len(df_full_test))
print(len(df_full_test['embedding'][0]))
# Out:
#                                            embedding  label        word
# 0  [-0.10669928789138794, 0.43782612681388855, -0...      1       apple
# 1  [0.14181819558143616, -0.05798260122537613, -0...      1      family
# 2  [0.03150975704193115, -0.0006562080234289169, ...      1       sound
# 3  [-0.296589732170105, 0.34292078018188477, 0.01...      1    keyboard
# 4  [-0.14427000284194946, 0.6225440502166748, -0....      1       anger
# 5  [0.4949460029602051, -0.3697931468486786, -0.3...      1         bus
# 6  [0.1132516860961914, -0.34453505277633667, -0....      1  conformity
# 7  [-0.13867831230163574, 0.16600413620471954, 0....      1         joy
# 8  [0.5639014840126038, 0.10567453503608704, -0.5...      1        fish
# 9  [0.4187287986278534, -0.42006465792655945, -0....      1     trading
# 147
# 768

# %%
full_train_loader, full_test_loader = create_dataloaders(df_full_train, df_full_test)

# take the best of 3 runs
full_best_test_acc = 0
full_best_test_f1 = 0

for i in range(10):
    net, full_best_combined_loss = train_model(full_train_loader, 768)

    # train_acc, train_f1 = evaluate_net(full_train_loader, net)
    test_acc, test_f1 = evaluate_net(full_test_loader, net)

    if test_acc > best_test_acc and test_f1 > best_test_f1:
        full_best_test_acc = test_acc
        full_best_test_f1 = test_f1

print(f'All axes best combined loss: {full_best_combined_loss}')
print(f'All axes best test f1: {full_best_test_f1:.4f}')
print(f'All axes best test accuracy: {full_best_test_acc*100:.2f}% \n')
# Out:
# All axes best combined loss: 0.47590216289972886
# All axes best test f1: 0.9383
# All axes best test accuracy: 93.20%

# %%
top_100_indices = np.argsort(all_test_accs_val)[-100:]

# %%
df_top100_train = pd.DataFrame(df_train[str(i)] for i in top_100_indices)
df_top100_train = df_top100_train.T

# combine all column values into list stored in one column
df_top100_train['embedding'] = df_top100_train.values.tolist()

# remove all columns except the list of embeddings
df_top100_train = df_top100_train[['embedding']]
df_top100_train['label'] = df_train['label']
df_top100_train['word'] = df_train['word']

print(df_top100_train[:10])
print(len(df_top100_train['embedding'][0]))

df_top100_test = pd.DataFrame(df_test[str(i)] for i in top_100_indices)
df_top100_test = df_top100_test.T

# combine all column values into list stored in one column
df_top100_test['embedding'] = df_top100_test.values.tolist()

# remove all columns except the list of embeddings
df_top100_test = df_top100_test[['embedding']]
df_top100_test['label'] = df_test['label']
df_top100_test['word'] = df_test['word']

print(df_top100_test[:10])
print(len(df_top100_test['embedding'][0]))

top100_train_loader, top100_test_loader = create_dataloaders(df_top100_train, df_top100_test)

# take the best of 3 runs
top100_best_test_acc = 0
top100_best_test_f1 = 0

for i in range(10):
    net, top100_best_combined_loss = train_model(top100_train_loader, 100)

    # train_acc, train_f1 = evaluate_net(top100_train_loader, net)
    test_acc, test_f1 = evaluate_net(top100_test_loader, net)

    if test_acc > best_test_acc and test_f1 > best_test_f1:
        top100_best_test_acc = test_acc
        top100_best_test_f1 = test_f1

print(f'Top 100 axes best combined loss: {top100_best_combined_loss}')
print(f'Top 100 axes best test f1: {top100_best_test_f1:.4f}')
print(f'Top 100 axes best test accuracy: {top100_best_test_acc*100:.2f}% \n')
# Out:
#                                            embedding  label      word
# 0  [0.67814040184021, 0.31599161028862, 0.0246190...      1    person
# 1  [0.44881439208984375, 0.2949472665786743, 0.24...      1      bear
# 2  [-0.09120746701955795, 0.036795616149902344, 0...      1      purr
# 3  [0.710121750831604, 0.16400624811649323, 0.280...      1      sink
# 4  [0.554070234298706, 0.3517981767654419, -0.077...      1      idea
# 5  [0.1365218311548233, -0.08016857504844666, 0.0...      1  opulence
# 6  [0.4766991138458252, 0.7229492664337158, 0.056...      1      line
# 7  [0.14465123414993286, 0.3400316536426544, 0.11...      1    clique
# 8  [0.19514691829681396, 0.0862727239727974, 0.09...      1      skis
# 9  [0.635877251625061, 0.35847848653793335, 0.655...      1      rain
# 100
#                                            embedding  label        word
# 0  [0.19969767332077026, -0.28366389870643616, -0...      1       apple
# 1  [0.5990967750549316, 0.48299023509025574, 0.29...      1      family
# 2  [0.7461085319519043, 0.13587696850299835, -0.0...      1       sound
# 3  [0.6540442109107971, -0.28378280997276306, 0.0...      1    keyboard
# 4  [0.8199666142463684, 0.11023173481225967, 0.42...      1       anger
# 5  [0.40382805466651917, 0.24101509153842926, 0.0...      1         bus
# 6  [0.6282579302787781, 0.2638762295246124, 0.007...      1  conformity
# 7  [0.593200147151947, 0.16047966480255127, 0.134...      1         joy
# 8  [0.31089967489242554, 0.22263489663600922, 0.2...      1        fish
# 9  [0.5358319878578186, 0.2084101140499115, 0.121...      1     trading
# 100
# Top 100 axes best combined loss: 4.9555285833776
# Top 100 axes best test f1: 0.9193
# Top 100 axes best test accuracy: 91.16%

# %%
print(f"Top 1 ({top_10_indices[-1]}) axis best test accuracy: {all_test_accs_val[top_10_indices[-1]]*100:.2f}%, f1: {all_test_f1s_val[top_10_indices[-1]]:.4f}, loss: {all_combined_losses[top_10_indices[-1]]}")
print(f"Top 10 axes best test accuracy: {top10_best_test_acc*100:.2f}%, f1: {top10_best_test_f1:.4f}, loss: {top10_best_combined_loss}")
print(f"Top 100 axes best test accuracy: {top100_best_test_acc*100:.2f}%, f1: {top100_best_test_f1:.4f}, loss: {top100_best_combined_loss}")
print(f"All 768 axes best test accuracy: {full_best_test_acc*100:.2f}%, f1: {full_best_test_f1:.4f}, loss: {full_best_combined_loss}")
# Out:
# Top 1 (215) axis best test accuracy: 78.91%, f1: 0.7919, loss: 20.974690437316895
# Top 10 axes best test accuracy: 85.71%, f1: 0.8662, loss: 12.64771082624793
# Top 100 axes best test accuracy: 91.16%, f1: 0.9193, loss: 4.9555285833776
# All 768 axes best test accuracy: 93.20%, f1: 0.9383, loss: 0.47590216289972886

# %%
df_summary = pd.DataFrame({
    'accuracy': [all_test_accs_val[top_10_indices[-1]], top10_best_test_acc, top100_best_test_acc, full_best_test_acc],
    'f1': [all_test_f1s_val[top_10_indices[-1]], top10_best_test_f1, top100_best_test_f1, full_best_test_f1],
    'loss': [all_combined_losses[top_10_indices[-1]], top10_best_combined_loss, top100_best_combined_loss, full_best_combined_loss]
})
df_summary.index = ['Top 1', 'Top 10', 'Top 100', '768 axes']

print(df_summary)

# save the dataframe to a csv file
df_summary.to_csv(f"llm-outputs/{classification}_xl_bruteforce_summary.csv", index=False)
# Out:
#           accuracy        f1       loss
# Top 1     0.789116  0.791946  20.974690
# Top 10    0.857143  0.866242  12.647711
# Top 100   0.911565  0.919255   4.955529
# 768 axes  0.931973  0.938272   0.475902
